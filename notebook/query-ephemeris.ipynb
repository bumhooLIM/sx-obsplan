# %%
import sxobsplan
from pathlib import Path
import pandas as pd

# %% [markdown]
# Refer the list of small-bodies from the database.
#
# e.g.)
# - [JPL Small-Body Database Query Tool](https://ssd.jpl.nasa.gov/tools/sbdb_query.html)

# %%
EPHDIR = Path("../eph")
EPHDIR.mkdir(exist_ok=True, parents=True)

# Small-Body Data Source: JPL SBDB
fpath_sbdb = Path("../data/sbdb_query_results_comet_ver250926.csv")
df_sbdb = pd.read_csv(fpath_sbdb)

# Filter database before queries
mask  = (df_sbdb.prefix != "D") # Remove destroyed comets
mask &= ~((df_sbdb.prefix == "C") & (df_sbdb.epoch_cal <= "2015-01-01")) # Old comets

df_sbdb_filtered = df_sbdb[mask]
df_sbdb_filtered.head()
# Out:
#      spkid             full_name pdes           name prefix  neo  pha  sats  \
# 0  1000036             1P/Halley   1P         Halley      P    Y  NaN     0
# 1  1000025              2P/Encke   2P          Encke      P    Y  NaN     0
# 3  1000026               4P/Faye   4P           Faye      P  NaN  NaN     0
# 5  1000017           6P/d'Arrest   6P       d'Arrest      P  NaN  NaN     0
# 6  1000069      7P/Pons-Winnecke   7P  Pons-Winnecke      P    Y  NaN     0
#
#     H   G  ...      rms  two_body            A1      A1_sigma            A2  \
# 0 NaN NaN  ...  0.61052       NaN  4.900000e-10  4.000000e-11  1.600000e-10
# 1 NaN NaN  ...  0.45260       NaN  2.500000e-10  6.400000e-11  3.500000e-13
# 3 NaN NaN  ...  0.54329       NaN  4.000000e-09  1.200000e-10  3.200000e-10
# 5 NaN NaN  ...  0.63861       NaN  1.800000e-10  2.700000e-10 -8.500000e-10
# 6 NaN NaN  ...  0.66978       NaN  6.400000e-11  3.600000e-13 -5.200000e-12
#
#        A2_sigma            A3      A3_sigma     DT  DT_sigma
# 0  4.600000e-15           NaN           NaN    NaN       NaN
# 1  4.100000e-12           NaN           NaN    NaN       NaN
# 3  6.300000e-11 -7.100000e-10  4.200000e-11  -37.7      2.17
# 5  1.200000e-10           NaN           NaN    NaN       NaN
# 6  5.000000e-13 -1.000000e-10  2.800000e-12  150.0      5.52
#
# [5 rows x 79 columns]

# %%
pdes_list = df_sbdb_filtered['pdes'].tolist()
epochs = {"start": "2025-01-01", "stop": "2027-12-31", "step": "5d"}

for pdes in pdes_list:

    # Check existing ephemeris
    fpath_eph = EPHDIR / f"{''.join(pdes.split())}.csv"
    try:
        assert not fpath_eph.exists()
    except AssertionError:
        print(f"Skip existing ephemeris: {fpath_eph}")
        continue

    # Query ephemeris
    eph = sxobsplan.fetch_with_fallback(
        pdes,
        epochs=epochs,
        quantities="1,3,9,18,19,20,22,23,24,25,27,28,29,33,43",
        location="500"
    )
    
    eph.write(fpath_eph, overwrite=False)
    print(f"Save ephemeris: {fpath_eph}")
# Out:
# Skip existing ephemeris: ../eph/1P.csv
# Skip existing ephemeris: ../eph/2P.csv
# Skip existing ephemeris: ../eph/4P.csv
# Skip existing ephemeris: ../eph/6P.csv
# Skip existing ephemeris: ../eph/7P.csv
# Skip existing ephemeris: ../eph/8P.csv
# Skip existing ephemeris: ../eph/9P.csv
# Skip existing ephemeris: ../eph/10P.csv
# Skip existing ephemeris: ../eph/11P.csv
# Skip existing ephemeris: ../eph/12P.csv
# Skip existing ephemeris: ../eph/13P.csv
# Skip existing ephemeris: ../eph/14P.csv
# Skip existing ephemeris: ../eph/15P.csv
# Skip existing ephemeris: ../eph/16P.csv
# Skip existing ephemeris: ../eph/17P.csv
# Skip existing ephemeris: ../eph/19P.csv
# Skip existing ephemeris: ../eph/21P.csv
# Skip existing ephemeris: ../eph/22P.csv
# Skip existing ephemeris: ../eph/23P.csv
# Skip existing ephemeris: ../eph/24P.csv
# Skip existing ephemeris: ../eph/26P.csv
# Skip existing ephemeris: ../eph/27P.csv
# Skip existing ephemeris: ../eph/28P.csv
# Skip existing ephemeris: ../eph/29P.csv
# Skip existing ephemeris: ../eph/30P.csv
# Skip existing ephemeris: ../eph/31P.csv
# Skip existing ephemeris: ../eph/32P.csv
# Skip existing ephemeris: ../eph/33P.csv
# Skip existing ephemeris: ../eph/35P.csv
# Skip existing ephemeris: ../eph/36P.csv
# Skip existing ephemeris: ../eph/37P.csv
# Skip existing ephemeris: ../eph/38P.csv
# Skip existing ephemeris: ../eph/39P.csv
# Skip existing ephemeris: ../eph/40P.csv
# Skip existing ephemeris: ../eph/41P.csv
# Skip existing ephemeris: ../eph/42P.csv
# Skip existing ephemeris: ../eph/43P.csv
# Skip existing ephemeris: ../eph/44P.csv
# Skip existing ephemeris: ../eph/45P.csv
# Skip existing ephemeris: ../eph/46P.csv
# Skip existing ephemeris: ../eph/47P.csv
# Skip existing ephemeris: ../eph/48P.csv
# Skip existing ephemeris: ../eph/49P.csv
# Skip existing ephemeris: ../eph/50P.csv
# Skip existing ephemeris: ../eph/51P.csv
# Skip existing ephemeris: ../eph/52P.csv
# Skip existing ephemeris: ../eph/53P.csv
# Skip existing ephemeris: ../eph/54P.csv
# Skip existing ephemeris: ../eph/55P.csv
# Skip existing ephemeris: ../eph/56P.csv
# Skip existing ephemeris: ../eph/57P.csv
# Skip existing ephemeris: ../eph/58P.csv
# Skip existing ephemeris: ../eph/59P.csv
# Skip existing ephemeris: ../eph/60P.csv
# Skip existing ephemeris: ../eph/61P.csv
# Skip existing ephemeris: ../eph/62P.csv
# Skip existing ephemeris: ../eph/63P.csv
# Skip existing ephemeris: ../eph/64P.csv
# Skip existing ephemeris: ../eph/65P.csv
# Skip existing ephemeris: ../eph/66P.csv
# Skip existing ephemeris: ../eph/67P.csv
# Skip existing ephemeris: ../eph/68P.csv
# Skip existing ephemeris: ../eph/69P.csv
# Skip existing ephemeris: ../eph/70P.csv
# Skip existing ephemeris: ../eph/71P.csv
# Skip existing ephemeris: ../eph/72P.csv
# Skip existing ephemeris: ../eph/73P.csv
# Skip existing ephemeris: ../eph/74P.csv
# Skip existing ephemeris: ../eph/76P.csv
# Skip existing ephemeris: ../eph/77P.csv
# Skip existing ephemeris: ../eph/78P.csv
# Skip existing ephemeris: ../eph/79P.csv
# Skip existing ephemeris: ../eph/80P.csv
# Skip existing ephemeris: ../eph/81P.csv
# Skip existing ephemeris: ../eph/82P.csv
# Skip existing ephemeris: ../eph/84P.csv
# Skip existing ephemeris: ../eph/86P.csv
# Skip existing ephemeris: ../eph/87P.csv
# Skip existing ephemeris: ../eph/88P.csv
# Skip existing ephemeris: ../eph/89P.csv
# Skip existing ephemeris: ../eph/90P.csv
# Skip existing ephemeris: ../eph/91P.csv
# Skip existing ephemeris: ../eph/92P.csv
# Skip existing ephemeris: ../eph/93P.csv
# Skip existing ephemeris: ../eph/94P.csv
# Skip existing ephemeris: ../eph/96P.csv
# Skip existing ephemeris: ../eph/97P.csv
# Skip existing ephemeris: ../eph/98P.csv
# Skip existing ephemeris: ../eph/99P.csv
# Skip existing ephemeris: ../eph/100P.csv
# Skip existing ephemeris: ../eph/101P.csv
# Skip existing ephemeris: ../eph/102P.csv
# Skip existing ephemeris: ../eph/103P.csv
# Skip existing ephemeris: ../eph/104P.csv
# Skip existing ephemeris: ../eph/105P.csv
# Skip existing ephemeris: ../eph/106P.csv
# Skip existing ephemeris: ../eph/108P.csv
# Skip existing ephemeris: ../eph/109P.csv
# Skip existing ephemeris: ../eph/110P.csv
# Skip existing ephemeris: ../eph/111P.csv
# Skip existing ephemeris: ../eph/112P.csv
# Skip existing ephemeris: ../eph/113P.csv
# Skip existing ephemeris: ../eph/114P.csv
# Skip existing ephemeris: ../eph/115P.csv
# Skip existing ephemeris: ../eph/116P.csv
# Skip existing ephemeris: ../eph/117P.csv
# Skip existing ephemeris: ../eph/118P.csv
# Skip existing ephemeris: ../eph/119P.csv
# Skip existing ephemeris: ../eph/120P.csv
# Skip existing ephemeris: ../eph/121P.csv
# Skip existing ephemeris: ../eph/122P.csv
# Skip existing ephemeris: ../eph/123P.csv
# Skip existing ephemeris: ../eph/124P.csv
# Skip existing ephemeris: ../eph/125P.csv
# Skip existing ephemeris: ../eph/126P.csv
# Skip existing ephemeris: ../eph/127P.csv
# Skip existing ephemeris: ../eph/128P.csv
# Skip existing ephemeris: ../eph/129P.csv
# Skip existing ephemeris: ../eph/130P.csv
# Skip existing ephemeris: ../eph/131P.csv
# Skip existing ephemeris: ../eph/132P.csv
# Skip existing ephemeris: ../eph/134P.csv
# Skip existing ephemeris: ../eph/135P.csv
# Skip existing ephemeris: ../eph/136P.csv
# Skip existing ephemeris: ../eph/137P.csv
# Skip existing ephemeris: ../eph/138P.csv
# Skip existing ephemeris: ../eph/139P.csv
# Skip existing ephemeris: ../eph/140P.csv
# Skip existing ephemeris: ../eph/141P.csv
# Skip existing ephemeris: ../eph/142P.csv
# Skip existing ephemeris: ../eph/143P.csv
# Skip existing ephemeris: ../eph/144P.csv
# Skip existing ephemeris: ../eph/145P.csv
# Skip existing ephemeris: ../eph/146P.csv
# Skip existing ephemeris: ../eph/147P.csv
# Skip existing ephemeris: ../eph/148P.csv
# Skip existing ephemeris: ../eph/149P.csv
# Skip existing ephemeris: ../eph/150P.csv
# Skip existing ephemeris: ../eph/151P.csv
# Skip existing ephemeris: ../eph/152P.csv
# Skip existing ephemeris: ../eph/153P.csv
# Skip existing ephemeris: ../eph/154P.csv
# Skip existing ephemeris: ../eph/155P.csv
# Skip existing ephemeris: ../eph/156P.csv
# Skip existing ephemeris: ../eph/157P.csv
# Skip existing ephemeris: ../eph/158P.csv
# Skip existing ephemeris: ../eph/159P.csv
# Skip existing ephemeris: ../eph/160P.csv
# Skip existing ephemeris: ../eph/161P.csv
# Skip existing ephemeris: ../eph/162P.csv
# Skip existing ephemeris: ../eph/163P.csv
# Skip existing ephemeris: ../eph/164P.csv
# Skip existing ephemeris: ../eph/165P.csv
# Skip existing ephemeris: ../eph/166P.csv
# Skip existing ephemeris: ../eph/167P.csv
# Skip existing ephemeris: ../eph/168P.csv
# Skip existing ephemeris: ../eph/169P.csv
# Skip existing ephemeris: ../eph/170P.csv
# Skip existing ephemeris: ../eph/171P.csv
# Skip existing ephemeris: ../eph/172P.csv
# Skip existing ephemeris: ../eph/173P.csv
# Skip existing ephemeris: ../eph/175P.csv
# Skip existing ephemeris: ../eph/177P.csv
# Skip existing ephemeris: ../eph/178P.csv
# Skip existing ephemeris: ../eph/179P.csv
# Skip existing ephemeris: ../eph/180P.csv
# Skip existing ephemeris: ../eph/181P.csv
# Skip existing ephemeris: ../eph/182P.csv
# Skip existing ephemeris: ../eph/183P.csv
# Skip existing ephemeris: ../eph/184P.csv
# Skip existing ephemeris: ../eph/185P.csv
# Skip existing ephemeris: ../eph/186P.csv
# Skip existing ephemeris: ../eph/187P.csv
# Skip existing ephemeris: ../eph/188P.csv
# Skip existing ephemeris: ../eph/189P.csv
# Skip existing ephemeris: ../eph/190P.csv
# Skip existing ephemeris: ../eph/191P.csv
# Skip existing ephemeris: ../eph/192P.csv
# Skip existing ephemeris: ../eph/193P.csv
# Skip existing ephemeris: ../eph/194P.csv
# Skip existing ephemeris: ../eph/195P.csv
# Skip existing ephemeris: ../eph/196P.csv
# Skip existing ephemeris: ../eph/197P.csv
# Skip existing ephemeris: ../eph/198P.csv
# Skip existing ephemeris: ../eph/199P.csv
# Skip existing ephemeris: ../eph/200P.csv
# Skip existing ephemeris: ../eph/201P.csv
# Skip existing ephemeris: ../eph/202P.csv
# Skip existing ephemeris: ../eph/203P.csv
# Skip existing ephemeris: ../eph/204P.csv
# Skip existing ephemeris: ../eph/205P.csv
# Skip existing ephemeris: ../eph/206P.csv
# Skip existing ephemeris: ../eph/207P.csv
# Skip existing ephemeris: ../eph/208P.csv
# Skip existing ephemeris: ../eph/209P.csv
# Skip existing ephemeris: ../eph/210P.csv
# Skip existing ephemeris: ../eph/211P.csv
# Skip existing ephemeris: ../eph/212P.csv
# Skip existing ephemeris: ../eph/213P.csv
# Skip existing ephemeris: ../eph/214P.csv
# Skip existing ephemeris: ../eph/215P.csv
# Skip existing ephemeris: ../eph/216P.csv
# Skip existing ephemeris: ../eph/217P.csv
# Skip existing ephemeris: ../eph/218P.csv
# Skip existing ephemeris: ../eph/219P.csv
# Skip existing ephemeris: ../eph/220P.csv
# Skip existing ephemeris: ../eph/221P.csv
# Skip existing ephemeris: ../eph/222P.csv
# Skip existing ephemeris: ../eph/223P.csv
# Skip existing ephemeris: ../eph/224P.csv
# Skip existing ephemeris: ../eph/225P.csv
# Skip existing ephemeris: ../eph/226P.csv
# Skip existing ephemeris: ../eph/227P.csv
# Skip existing ephemeris: ../eph/228P.csv
# Skip existing ephemeris: ../eph/229P.csv
# Skip existing ephemeris: ../eph/230P.csv
# Skip existing ephemeris: ../eph/231P.csv
# Skip existing ephemeris: ../eph/232P.csv
# Skip existing ephemeris: ../eph/233P.csv
# Skip existing ephemeris: ../eph/234P.csv
# Skip existing ephemeris: ../eph/235P.csv
# Skip existing ephemeris: ../eph/236P.csv
# Skip existing ephemeris: ../eph/237P.csv
# Skip existing ephemeris: ../eph/238P.csv
# Skip existing ephemeris: ../eph/239P.csv
# Skip existing ephemeris: ../eph/240P.csv
# Skip existing ephemeris: ../eph/241P.csv
# Skip existing ephemeris: ../eph/242P.csv
# Skip existing ephemeris: ../eph/243P.csv
# Skip existing ephemeris: ../eph/244P.csv
# Skip existing ephemeris: ../eph/245P.csv
# Skip existing ephemeris: ../eph/246P.csv
# Skip existing ephemeris: ../eph/247P.csv
# Skip existing ephemeris: ../eph/248P.csv
# Skip existing ephemeris: ../eph/249P.csv
# Skip existing ephemeris: ../eph/250P.csv
# Skip existing ephemeris: ../eph/251P.csv
# Skip existing ephemeris: ../eph/252P.csv
# Skip existing ephemeris: ../eph/253P.csv
# Skip existing ephemeris: ../eph/254P.csv
# Skip existing ephemeris: ../eph/255P.csv
# Skip existing ephemeris: ../eph/256P.csv
# Skip existing ephemeris: ../eph/257P.csv
# Skip existing ephemeris: ../eph/258P.csv
# Skip existing ephemeris: ../eph/259P.csv
# Skip existing ephemeris: ../eph/260P.csv
# Skip existing ephemeris: ../eph/261P.csv
# Skip existing ephemeris: ../eph/262P.csv
# Skip existing ephemeris: ../eph/263P.csv
# Skip existing ephemeris: ../eph/264P.csv
# Skip existing ephemeris: ../eph/265P.csv
# Skip existing ephemeris: ../eph/266P.csv
# Skip existing ephemeris: ../eph/267P.csv
# Skip existing ephemeris: ../eph/268P.csv
# Skip existing ephemeris: ../eph/269P.csv
# Skip existing ephemeris: ../eph/270P.csv
# Skip existing ephemeris: ../eph/271P.csv
# Skip existing ephemeris: ../eph/272P.csv
# Skip existing ephemeris: ../eph/273P.csv
# Skip existing ephemeris: ../eph/274P.csv
# Skip existing ephemeris: ../eph/275P.csv
# Skip existing ephemeris: ../eph/276P.csv
# Skip existing ephemeris: ../eph/277P.csv
# Skip existing ephemeris: ../eph/278P.csv
# Skip existing ephemeris: ../eph/279P.csv
# Skip existing ephemeris: ../eph/280P.csv
# Skip existing ephemeris: ../eph/281P.csv
# Skip existing ephemeris: ../eph/283P.csv
# Skip existing ephemeris: ../eph/284P.csv
# Skip existing ephemeris: ../eph/285P.csv
# Skip existing ephemeris: ../eph/286P.csv
# Skip existing ephemeris: ../eph/287P.csv
# Skip existing ephemeris: ../eph/289P.csv
# Skip existing ephemeris: ../eph/290P.csv
# Skip existing ephemeris: ../eph/291P.csv
# Skip existing ephemeris: ../eph/292P.csv
# Skip existing ephemeris: ../eph/293P.csv
# Skip existing ephemeris: ../eph/294P.csv
# Skip existing ephemeris: ../eph/295P.csv
# Skip existing ephemeris: ../eph/296P.csv
# Skip existing ephemeris: ../eph/297P.csv
# Skip existing ephemeris: ../eph/298P.csv
# Skip existing ephemeris: ../eph/299P.csv
# Skip existing ephemeris: ../eph/300P.csv
# Skip existing ephemeris: ../eph/301P.csv
# Skip existing ephemeris: ../eph/302P.csv
# Skip existing ephemeris: ../eph/303P.csv
# Skip existing ephemeris: ../eph/304P.csv
# Skip existing ephemeris: ../eph/305P.csv
# Skip existing ephemeris: ../eph/306P.csv
# Skip existing ephemeris: ../eph/307P.csv
# Skip existing ephemeris: ../eph/308P.csv
# Skip existing ephemeris: ../eph/309P.csv
# Skip existing ephemeris: ../eph/310P.csv
# Skip existing ephemeris: ../eph/311P.csv
# Skip existing ephemeris: ../eph/312P.csv
# Skip existing ephemeris: ../eph/313P.csv
# Skip existing ephemeris: ../eph/314P.csv
# Skip existing ephemeris: ../eph/315P.csv
# Skip existing ephemeris: ../eph/316P.csv
# Skip existing ephemeris: ../eph/317P.csv
# Skip existing ephemeris: ../eph/318P.csv
# Skip existing ephemeris: ../eph/319P.csv
# Skip existing ephemeris: ../eph/320P.csv
# Skip existing ephemeris: ../eph/321P.csv
# Skip existing ephemeris: ../eph/322P.csv
# Skip existing ephemeris: ../eph/323P.csv
# Skip existing ephemeris: ../eph/324P.csv
# Skip existing ephemeris: ../eph/325P.csv
# Skip existing ephemeris: ../eph/326P.csv
# Skip existing ephemeris: ../eph/327P.csv
# Skip existing ephemeris: ../eph/328P.csv
# Skip existing ephemeris: ../eph/329P.csv
# Skip existing ephemeris: ../eph/330P.csv
# Skip existing ephemeris: ../eph/331P.csv
# Skip existing ephemeris: ../eph/332P.csv
# Skip existing ephemeris: ../eph/333P.csv
# Skip existing ephemeris: ../eph/334P.csv
# Skip existing ephemeris: ../eph/335P.csv
# Skip existing ephemeris: ../eph/336P.csv
# Skip existing ephemeris: ../eph/337P.csv
# Skip existing ephemeris: ../eph/338P.csv
# Skip existing ephemeris: ../eph/339P.csv
# Skip existing ephemeris: ../eph/340P.csv
# Skip existing ephemeris: ../eph/341P.csv
# Skip existing ephemeris: ../eph/342P.csv
# Skip existing ephemeris: ../eph/343P.csv
# Skip existing ephemeris: ../eph/344P.csv
# Skip existing ephemeris: ../eph/345P.csv
# Skip existing ephemeris: ../eph/346P.csv
# Skip existing ephemeris: ../eph/347P.csv
# Skip existing ephemeris: ../eph/348P.csv
# Skip existing ephemeris: ../eph/349P.csv
# Skip existing ephemeris: ../eph/350P.csv
# Skip existing ephemeris: ../eph/351P.csv
# Skip existing ephemeris: ../eph/352P.csv
# Skip existing ephemeris: ../eph/353P.csv
# Skip existing ephemeris: ../eph/354P.csv
# Skip existing ephemeris: ../eph/355P.csv
# Skip existing ephemeris: ../eph/356P.csv
# Skip existing ephemeris: ../eph/357P.csv
# Skip existing ephemeris: ../eph/358P.csv
# Skip existing ephemeris: ../eph/359P.csv
# Skip existing ephemeris: ../eph/360P.csv
# Skip existing ephemeris: ../eph/361P.csv
# Skip existing ephemeris: ../eph/363P.csv
# Skip existing ephemeris: ../eph/364P.csv
# Skip existing ephemeris: ../eph/365P.csv
# Skip existing ephemeris: ../eph/366P.csv
# Skip existing ephemeris: ../eph/367P.csv
# Skip existing ephemeris: ../eph/368P.csv
# Skip existing ephemeris: ../eph/369P.csv
# Skip existing ephemeris: ../eph/370P.csv
# Skip existing ephemeris: ../eph/371P.csv
# Skip existing ephemeris: ../eph/372P.csv
# Skip existing ephemeris: ../eph/373P.csv
# Skip existing ephemeris: ../eph/374P.csv
# Skip existing ephemeris: ../eph/375P.csv
# Skip existing ephemeris: ../eph/376P.csv
# Skip existing ephemeris: ../eph/377P.csv
# Skip existing ephemeris: ../eph/378P.csv
# Skip existing ephemeris: ../eph/379P.csv
# Skip existing ephemeris: ../eph/380P.csv
# Skip existing ephemeris: ../eph/381P.csv
# Skip existing ephemeris: ../eph/382P.csv
# Skip existing ephemeris: ../eph/383P.csv
# Skip existing ephemeris: ../eph/384P.csv
# Skip existing ephemeris: ../eph/385P.csv
# Skip existing ephemeris: ../eph/386P.csv
# Skip existing ephemeris: ../eph/387P.csv
# Skip existing ephemeris: ../eph/388P.csv
# Skip existing ephemeris: ../eph/389P.csv
# Skip existing ephemeris: ../eph/390P.csv
# Skip existing ephemeris: ../eph/391P.csv
# Skip existing ephemeris: ../eph/392P.csv
# Skip existing ephemeris: ../eph/393P.csv
# Skip existing ephemeris: ../eph/394P.csv
# Skip existing ephemeris: ../eph/395P.csv
# Skip existing ephemeris: ../eph/396P.csv
# Skip existing ephemeris: ../eph/397P.csv
# Skip existing ephemeris: ../eph/398P.csv
# Skip existing ephemeris: ../eph/399P.csv
# Skip existing ephemeris: ../eph/400P.csv
# Skip existing ephemeris: ../eph/401P.csv
# Skip existing ephemeris: ../eph/402P.csv
# Skip existing ephemeris: ../eph/403P.csv
# Skip existing ephemeris: ../eph/404P.csv
# Skip existing ephemeris: ../eph/405P.csv
# Skip existing ephemeris: ../eph/406P.csv
# Skip existing ephemeris: ../eph/407P.csv
# Skip existing ephemeris: ../eph/408P.csv
# Skip existing ephemeris: ../eph/409P.csv
# Skip existing ephemeris: ../eph/410P.csv
# Skip existing ephemeris: ../eph/411P.csv
# Skip existing ephemeris: ../eph/412P.csv
# Skip existing ephemeris: ../eph/413P.csv
# Skip existing ephemeris: ../eph/414P.csv
# Skip existing ephemeris: ../eph/415P.csv
# Skip existing ephemeris: ../eph/416P.csv
# Skip existing ephemeris: ../eph/417P.csv
# Skip existing ephemeris: ../eph/418P.csv
# Skip existing ephemeris: ../eph/419P.csv
# Skip existing ephemeris: ../eph/420P.csv
# Skip existing ephemeris: ../eph/421P.csv
# Skip existing ephemeris: ../eph/422P.csv
# Skip existing ephemeris: ../eph/423P.csv
# Skip existing ephemeris: ../eph/424P.csv
# Skip existing ephemeris: ../eph/425P.csv
# Skip existing ephemeris: ../eph/426P.csv
# Skip existing ephemeris: ../eph/427P.csv
# Skip existing ephemeris: ../eph/428P.csv
# Skip existing ephemeris: ../eph/429P.csv
# Skip existing ephemeris: ../eph/430P.csv
# Skip existing ephemeris: ../eph/431P.csv
# Skip existing ephemeris: ../eph/432P.csv
# Skip existing ephemeris: ../eph/434P.csv
# Skip existing ephemeris: ../eph/435P.csv
# Skip existing ephemeris: ../eph/436P.csv
# Skip existing ephemeris: ../eph/437P.csv
# Skip existing ephemeris: ../eph/438P.csv
# Skip existing ephemeris: ../eph/439P.csv
# Skip existing ephemeris: ../eph/440P.csv
# Skip existing ephemeris: ../eph/441P.csv
# Skip existing ephemeris: ../eph/442P.csv
# Skip existing ephemeris: ../eph/443P.csv
# Skip existing ephemeris: ../eph/444P.csv
# Skip existing ephemeris: ../eph/445P.csv
# Skip existing ephemeris: ../eph/446P.csv
# Skip existing ephemeris: ../eph/447P.csv
# Skip existing ephemeris: ../eph/448P.csv
# Skip existing ephemeris: ../eph/449P.csv
# Skip existing ephemeris: ../eph/450P.csv
# Skip existing ephemeris: ../eph/451P.csv
# Skip existing ephemeris: ../eph/452P.csv
# Skip existing ephemeris: ../eph/453P.csv
# Skip existing ephemeris: ../eph/454P.csv
# Skip existing ephemeris: ../eph/455P.csv
# Skip existing ephemeris: ../eph/456P.csv
# Skip existing ephemeris: ../eph/457P.csv
# Skip existing ephemeris: ../eph/458P.csv
# Skip existing ephemeris: ../eph/459P.csv
# Skip existing ephemeris: ../eph/460P.csv
# Skip existing ephemeris: ../eph/461P.csv
# Skip existing ephemeris: ../eph/462P.csv
# Skip existing ephemeris: ../eph/463P.csv
# Skip existing ephemeris: ../eph/464P.csv
# Skip existing ephemeris: ../eph/465P.csv
# Skip existing ephemeris: ../eph/466P.csv
# Skip existing ephemeris: ../eph/467P.csv
# Skip existing ephemeris: ../eph/468P.csv
# Skip existing ephemeris: ../eph/469P.csv
# Skip existing ephemeris: ../eph/470P.csv
# Skip existing ephemeris: ../eph/471P.csv
# Skip existing ephemeris: ../eph/472P.csv
# Skip existing ephemeris: ../eph/473P.csv
# Skip existing ephemeris: ../eph/474P.csv
# Skip existing ephemeris: ../eph/475P.csv
# Skip existing ephemeris: ../eph/476P.csv
# Skip existing ephemeris: ../eph/477P.csv
# Skip existing ephemeris: ../eph/478P.csv
# Skip existing ephemeris: ../eph/479P.csv
# Skip existing ephemeris: ../eph/480P.csv
# Skip existing ephemeris: ../eph/481P.csv
# Skip existing ephemeris: ../eph/482P.csv
# Skip existing ephemeris: ../eph/484P.csv
# Skip existing ephemeris: ../eph/485P.csv
# Skip existing ephemeris: ../eph/486P.csv
# Skip existing ephemeris: ../eph/487P.csv
# Skip existing ephemeris: ../eph/488P.csv
# Skip existing ephemeris: ../eph/489P.csv
# Skip existing ephemeris: ../eph/490P.csv
# Skip existing ephemeris: ../eph/491P.csv
# Skip existing ephemeris: ../eph/492P.csv
# Skip existing ephemeris: ../eph/493P.csv
# Skip existing ephemeris: ../eph/494P.csv
# Skip existing ephemeris: ../eph/495P.csv
# Skip existing ephemeris: ../eph/496P.csv
# Skip existing ephemeris: ../eph/497P.csv
# Skip existing ephemeris: ../eph/498P.csv
# Skip existing ephemeris: ../eph/499P.csv
# Skip existing ephemeris: ../eph/500P.csv
# Skip existing ephemeris: ../eph/501P.csv
# Skip existing ephemeris: ../eph/502P.csv
# Skip existing ephemeris: ../eph/503P.csv
# Skip existing ephemeris: ../eph/504P.csv
# Skip existing ephemeris: ../eph/505P.csv
# Skip existing ephemeris: ../eph/506P.csv
# Skip existing ephemeris: ../eph/507P.csv
# Skip existing ephemeris: ../eph/508P.csv
# Skip existing ephemeris: ../eph/509P.csv
# Skip existing ephemeris: ../eph/510P.csv
# Skip existing ephemeris: ../eph/1995O1.csv
# Skip existing ephemeris: ../eph/1996R2.csv
# Skip existing ephemeris: ../eph/1998VS24.csv
# Skip existing ephemeris: ../eph/1999J6.csv
# Skip existing ephemeris: ../eph/1999RO28.csv
# Skip existing ephemeris: ../eph/1999XN120.csv
# Skip existing ephemeris: ../eph/2000R2.csv
# Skip existing ephemeris: ../eph/2001H5.csv
# Skip existing ephemeris: ../eph/2002EJ57.csv
# Skip existing ephemeris: ../eph/2002P2.csv
# Skip existing ephemeris: ../eph/2002S7.csv
# Skip existing ephemeris: ../eph/2003F2.csv
# Skip existing ephemeris: ../eph/2003T12.csv
# Skip existing ephemeris: ../eph/2004FY140.csv
# Skip existing ephemeris: ../eph/2004R3.csv
# Skip existing ephemeris: ../eph/2005E1.csv
# Skip existing ephemeris: ../eph/2005L1.csv
# Skip existing ephemeris: ../eph/2005S2.csv
# Skip existing ephemeris: ../eph/2005T3.csv
# Skip existing ephemeris: ../eph/2005T4.csv
# Skip existing ephemeris: ../eph/2005T5.csv
# Skip existing ephemeris: ../eph/2006HR30.csv
# Skip existing ephemeris: ../eph/2007K2.csv
# Skip existing ephemeris: ../eph/2007Q2.csv
# Skip existing ephemeris: ../eph/2007S1.csv
# Skip existing ephemeris: ../eph/2007T2.csv
# Skip existing ephemeris: ../eph/2008O3.csv
# Skip existing ephemeris: ../eph/2008Y3.csv
# Skip existing ephemeris: ../eph/2008Y12.csv
# Skip existing ephemeris: ../eph/2009B1.csv
# Skip existing ephemeris: ../eph/2009O3.csv
# Skip existing ephemeris: ../eph/2009Q5.csv
# Skip existing ephemeris: ../eph/2009T2.csv
# Skip existing ephemeris: ../eph/2009WX51.csv
# Skip existing ephemeris: ../eph/2009Y2.csv
# Skip existing ephemeris: ../eph/2010C1.csv
# Skip existing ephemeris: ../eph/2010D2.csv
# Skip existing ephemeris: ../eph/2010E2.csv
# Skip existing ephemeris: ../eph/2010H2.csv
# Skip existing ephemeris: ../eph/2010H4.csv
# Skip existing ephemeris: ../eph/2010H5.csv
# Skip existing ephemeris: ../eph/2010J3.csv
# Skip existing ephemeris: ../eph/2010JC81.csv
# Skip existing ephemeris: ../eph/2010T2.csv
# Skip existing ephemeris: ../eph/2010U3.csv
# Skip existing ephemeris: ../eph/2010UH55.csv
# Skip existing ephemeris: ../eph/2011C2.csv
# Skip existing ephemeris: ../eph/2011FR143.csv
# Skip existing ephemeris: ../eph/2011JB15.csv
# Skip existing ephemeris: ../eph/2011KP36.csv
# Skip existing ephemeris: ../eph/2011N1.csv
# Skip existing ephemeris: ../eph/2011P1.csv
# Skip existing ephemeris: ../eph/2011S1.csv
# Skip existing ephemeris: ../eph/2011V1.csv
# Skip existing ephemeris: ../eph/2011W1.csv
# Skip existing ephemeris: ../eph/2011Y2.csv
# Skip existing ephemeris: ../eph/2012B1.csv
# Skip existing ephemeris: ../eph/2012C3.csv
# Skip existing ephemeris: ../eph/2012F2.csv
# Skip existing ephemeris: ../eph/2012G1.csv
# Skip existing ephemeris: ../eph/2012K3.csv
# Skip existing ephemeris: ../eph/2012LP26.csv
# Skip existing ephemeris: ../eph/2012NJ.csv
# Skip existing ephemeris: ../eph/2012O1.csv
# Skip existing ephemeris: ../eph/2012O2.csv
# Skip existing ephemeris: ../eph/2012T2.csv
# Skip existing ephemeris: ../eph/2012T3.csv
# Skip existing ephemeris: ../eph/2012U2.csv
# Skip existing ephemeris: ../eph/2013A1.csv
# Skip existing ephemeris: ../eph/2013AL76.csv
# Skip existing ephemeris: ../eph/2013C2.csv
# Skip existing ephemeris: ../eph/2013G1.csv
# Skip existing ephemeris: ../eph/2013G4.csv
# Skip existing ephemeris: ../eph/2013J2.csv
# Skip existing ephemeris: ../eph/2013N3.csv
# Skip existing ephemeris: ../eph/2013N5.csv
# Skip existing ephemeris: ../eph/2013P1.csv
# Skip existing ephemeris: ../eph/2013R3.csv
# Skip existing ephemeris: ../eph/2013T1.csv
# Skip existing ephemeris: ../eph/2013T2.csv
# Skip existing ephemeris: ../eph/2013US10.csv
# Skip existing ephemeris: ../eph/2013V4.csv
# Skip existing ephemeris: ../eph/2013W1.csv
# Skip existing ephemeris: ../eph/2013W2.csv
# Skip existing ephemeris: ../eph/2013X1.csv
# Skip existing ephemeris: ../eph/2013YG46.csv
# Skip existing ephemeris: ../eph/2014A2.csv
# Skip existing ephemeris: ../eph/2014A4.csv
# Skip existing ephemeris: ../eph/2014B1.csv
# Skip existing ephemeris: ../eph/2014C1.csv
# Skip existing ephemeris: ../eph/2014F3.csv
# Skip existing ephemeris: ../eph/2014HU195.csv
# Skip existing ephemeris: ../eph/2014L2.csv
# Skip existing ephemeris: ../eph/2014L3.csv
# Skip existing ephemeris: ../eph/2014M1.csv
# Skip existing ephemeris: ../eph/2014M4.csv
# Skip existing ephemeris: ../eph/2014N3.csv
# Skip existing ephemeris: ../eph/2014O3.csv
# Skip existing ephemeris: ../eph/2014OE4.csv
# Skip existing ephemeris: ../eph/2014OG392.csv
# Skip existing ephemeris: ../eph/2014Q1.csv
# Skip existing ephemeris: ../eph/2014Q2.csv
# Skip existing ephemeris: ../eph/2014R1.csv
# Skip existing ephemeris: ../eph/2014R3.csv
# Skip existing ephemeris: ../eph/2014S2.csv
# Skip existing ephemeris: ../eph/2014U4.csv
# Skip existing ephemeris: ../eph/2014UN271.csv
# Skip existing ephemeris: ../eph/2014V1.csv
# Skip existing ephemeris: ../eph/2014W2.csv
# Skip existing ephemeris: ../eph/2014W3.csv
# Skip existing ephemeris: ../eph/2014W4.csv
# Skip existing ephemeris: ../eph/2014W5.csv
# Skip existing ephemeris: ../eph/2014W6.csv
# Skip existing ephemeris: ../eph/2014W9.csv
# Skip existing ephemeris: ../eph/2014W11.csv
# Skip existing ephemeris: ../eph/2014X1.csv
# Skip existing ephemeris: ../eph/2014XB8.csv
# Skip existing ephemeris: ../eph/2014Y1.csv
# Skip existing ephemeris: ../eph/2015A1.csv
# Skip existing ephemeris: ../eph/2015A2.csv
# Skip existing ephemeris: ../eph/2015A3.csv
# Skip existing ephemeris: ../eph/2015B1.csv
# Skip existing ephemeris: ../eph/2015B2.csv
# Skip existing ephemeris: ../eph/2015B4.csv
# Skip existing ephemeris: ../eph/2015C1.csv
# Skip existing ephemeris: ../eph/2015C2.csv
# Skip existing ephemeris: ../eph/2015D1.csv
# Skip existing ephemeris: ../eph/2015D2.csv
# Skip existing ephemeris: ../eph/2015D3.csv
# Skip existing ephemeris: ../eph/2015D4.csv
# Skip existing ephemeris: ../eph/2015D5.csv
# Skip existing ephemeris: ../eph/2015D6.csv
# Skip existing ephemeris: ../eph/2015ER61.csv
# Skip existing ephemeris: ../eph/2015F2.csv
# Skip existing ephemeris: ../eph/2015F3.csv
# Skip existing ephemeris: ../eph/2015F4.csv
# Skip existing ephemeris: ../eph/2015F5.csv
# Skip existing ephemeris: ../eph/2015GX.csv
# Skip existing ephemeris: ../eph/2015G2.csv
# Skip existing ephemeris: ../eph/2015H1.csv
# Skip existing ephemeris: ../eph/2015H2.csv
# Skip existing ephemeris: ../eph/2015J1.csv
# Skip existing ephemeris: ../eph/2015J2.csv
# Skip existing ephemeris: ../eph/2015K1.csv
# Skip existing ephemeris: ../eph/2015K2.csv
# Skip existing ephemeris: ../eph/2015K4.csv
# Skip existing ephemeris: ../eph/2015K5.csv
# Skip existing ephemeris: ../eph/2015LC2.csv
# Skip existing ephemeris: ../eph/2015M1.csv
# Skip existing ephemeris: ../eph/2015M2.csv
# Skip existing ephemeris: ../eph/2015M3.csv
# Skip existing ephemeris: ../eph/2015O1.csv
# Skip existing ephemeris: ../eph/2015P3.csv
# Skip existing ephemeris: ../eph/2015P4.csv
# Skip existing ephemeris: ../eph/2015PD229.csv
# Skip existing ephemeris: ../eph/2015Q2.csv
# Skip existing ephemeris: ../eph/2015R1.csv
# Skip existing ephemeris: ../eph/2015R2.csv
# Skip existing ephemeris: ../eph/2015R3.csv
# Skip existing ephemeris: ../eph/2015T2.csv
# Skip existing ephemeris: ../eph/2015T4.csv
# Skip existing ephemeris: ../eph/2015T5.csv
# Skip existing ephemeris: ../eph/2015TO19.csv
# Skip existing ephemeris: ../eph/2015TP200.csv
# Skip existing ephemeris: ../eph/2015TQ209.csv
# Skip existing ephemeris: ../eph/2015V1.csv
# Skip existing ephemeris: ../eph/2015V2.csv
# Skip existing ephemeris: ../eph/2015V3.csv
# Skip existing ephemeris: ../eph/2015V4.csv
# Skip existing ephemeris: ../eph/2015VL62.csv
# Skip existing ephemeris: ../eph/2015WZ.csv
# Skip existing ephemeris: ../eph/2015W1.csv
# Skip existing ephemeris: ../eph/2015W2.csv
# Skip existing ephemeris: ../eph/2015XY1.csv
# Skip existing ephemeris: ../eph/2015X2.csv
# Skip existing ephemeris: ../eph/2015X3.csv
# Skip existing ephemeris: ../eph/2015X4.csv
# Skip existing ephemeris: ../eph/2015X5.csv
# Skip existing ephemeris: ../eph/2015X6.csv
# Skip existing ephemeris: ../eph/2015X7.csv
# Skip existing ephemeris: ../eph/2015X8.csv
# Skip existing ephemeris: ../eph/2015Y1.csv
# Skip existing ephemeris: ../eph/2015YG1.csv
# Skip existing ephemeris: ../eph/2016A1.csv
# Skip existing ephemeris: ../eph/2016A3.csv
# Skip existing ephemeris: ../eph/2016A5.csv
# Skip existing ephemeris: ../eph/2016A6.csv
# Skip existing ephemeris: ../eph/2016A7.csv
# Skip existing ephemeris: ../eph/2016A8.csv
# Skip existing ephemeris: ../eph/2016B1.csv
# Skip existing ephemeris: ../eph/2016C1.csv
# Skip existing ephemeris: ../eph/2016C2.csv
# Skip existing ephemeris: ../eph/2016E1.csv
# Skip existing ephemeris: ../eph/2016E2.csv
# Skip existing ephemeris: ../eph/2016G1.csv
# Skip existing ephemeris: ../eph/2016J2.csv
# Skip existing ephemeris: ../eph/2016KA.csv
# Skip existing ephemeris: ../eph/2016K1.csv
# Skip existing ephemeris: ../eph/2016M1.csv
# Skip existing ephemeris: ../eph/2016N4.csv
# Skip existing ephemeris: ../eph/2016N6.csv
# Skip existing ephemeris: ../eph/2016P1.csv
# Skip existing ephemeris: ../eph/2016P4.csv
# Skip existing ephemeris: ../eph/2016P5.csv
# Skip existing ephemeris: ../eph/2016Q2.csv
# Skip existing ephemeris: ../eph/2016Q4.csv
# Skip existing ephemeris: ../eph/2016R2.csv
# Skip existing ephemeris: ../eph/2016R3.csv
# Skip existing ephemeris: ../eph/2016R4.csv
# Skip existing ephemeris: ../eph/2016S1.csv
# Skip existing ephemeris: ../eph/2016T1.csv
# Skip existing ephemeris: ../eph/2016T2.csv
# Skip existing ephemeris: ../eph/2016T3.csv
# Skip existing ephemeris: ../eph/2016U1.csv
# Skip existing ephemeris: ../eph/2016VZ18.csv
# Skip existing ephemeris: ../eph/2016WM48.csv
# Skip existing ephemeris: ../eph/2016X1.csv
# Skip existing ephemeris: ../eph/2017A1.csv
# Skip existing ephemeris: ../eph/2017A3.csv
# Skip existing ephemeris: ../eph/2017AB5.csv
# Skip existing ephemeris: ../eph/2017B3.csv
# Skip existing ephemeris: ../eph/2017B4.csv
# Skip existing ephemeris: ../eph/2017C1.csv
# Skip existing ephemeris: ../eph/2017C2.csv
# Skip existing ephemeris: ../eph/2017D1.csv
# Skip existing ephemeris: ../eph/2017D2.csv
# Skip existing ephemeris: ../eph/2017D3.csv
# Skip existing ephemeris: ../eph/2017D4.csv
# Skip existing ephemeris: ../eph/2017D5.csv
# Skip existing ephemeris: ../eph/2017E1.csv
# Skip existing ephemeris: ../eph/2017E2.csv
# Skip existing ephemeris: ../eph/2017E3.csv
# Skip existing ephemeris: ../eph/2017E4.csv
# Skip existing ephemeris: ../eph/2017E5.csv
# Skip existing ephemeris: ../eph/2017F1.csv
# Skip existing ephemeris: ../eph/2017F2.csv
# Skip existing ephemeris: ../eph/2017FL36.csv
# Skip existing ephemeris: ../eph/2017G1.csv
# Skip existing ephemeris: ../eph/2017G2.csv
# Skip existing ephemeris: ../eph/2017G3.csv
# Skip existing ephemeris: ../eph/2017K1.csv
# Skip existing ephemeris: ../eph/2017K2.csv
# Save ephemeris: ../eph/2017K3.csv
# Save ephemeris: ../eph/2017K4.csv
# Save ephemeris: ../eph/2017K5.csv
# Save ephemeris: ../eph/2017K6.csv
# Save ephemeris: ../eph/2017M3.csv
# Save ephemeris: ../eph/2017M4.csv
# Save ephemeris: ../eph/2017M5.csv
# Save ephemeris: ../eph/2017O1.csv
# Save ephemeris: ../eph/2017P1.csv
# Save ephemeris: ../eph/2017P2.csv
# Save ephemeris: ../eph/2017S2.csv
# Save ephemeris: ../eph/2017S3.csv
# Save ephemeris: ../eph/2017S6.csv
# Save ephemeris: ../eph/2017S7.csv
# Save ephemeris: ../eph/2017S8.csv
# Save ephemeris: ../eph/2017T1.csv
# Save ephemeris: ../eph/2017T2.csv
# Save ephemeris: ../eph/2017T3.csv
# Save ephemeris: ../eph/2017TW13.csv
# Save ephemeris: ../eph/2017U2.csv
# Save ephemeris: ../eph/2017U3.csv
# Save ephemeris: ../eph/2017U4.csv
# Save ephemeris: ../eph/2017U5.csv
# Save ephemeris: ../eph/2017U7.csv
# Save ephemeris: ../eph/2017W2.csv
# Save ephemeris: ../eph/2017W3.csv
# Save ephemeris: ../eph/2017X1.csv
# Save ephemeris: ../eph/2017Y1.csv
# Save ephemeris: ../eph/2017Y2.csv
# Save ephemeris: ../eph/2017Y3.csv
# Save ephemeris: ../eph/2018A1.csv
# Save ephemeris: ../eph/2018A3.csv
# Save ephemeris: ../eph/2018A4.csv
# Save ephemeris: ../eph/2018A5.csv
# Save ephemeris: ../eph/2018A6.csv
# Save ephemeris: ../eph/2018B1.csv
# Save ephemeris: ../eph/2018C1.csv
# Save ephemeris: ../eph/2018C2.csv
# Save ephemeris: ../eph/2018DO4.csv
# Save ephemeris: ../eph/2018E1.csv
# Save ephemeris: ../eph/2018E2.csv
# Save ephemeris: ../eph/2018EN4.csv
# Save ephemeris: ../eph/2018EF9.csv
# Save ephemeris: ../eph/2018F1.csv
# Save ephemeris: ../eph/2018F3.csv
# 2025-09-26 14:38:18,604 [INFO] Non-unique id for '2018 F4'. Retrying with record #90004482 ...
# Save ephemeris: ../eph/2018F4.csv
# Save ephemeris: ../eph/2018H2.csv
# Save ephemeris: ../eph/2018K1.csv
# Save ephemeris: ../eph/2018KJ3.csv
# Save ephemeris: ../eph/2018L2.csv
# Save ephemeris: ../eph/2018L4.csv
# Save ephemeris: ../eph/2018M1.csv
# Save ephemeris: ../eph/2018N1.csv
# Save ephemeris: ../eph/2018N2.csv
# Save ephemeris: ../eph/2018O1.csv
# Save ephemeris: ../eph/2018P4.csv
# Save ephemeris: ../eph/2018P5.csv
# Save ephemeris: ../eph/2018R3.csv
# Save ephemeris: ../eph/2018R4.csv
# Save ephemeris: ../eph/2018R5.csv
# Save ephemeris: ../eph/2018S2.csv
# Save ephemeris: ../eph/2018S3.csv
# Save ephemeris: ../eph/2018U1.csv
# Save ephemeris: ../eph/2018V1.csv
# Save ephemeris: ../eph/2018V2.csv
# Save ephemeris: ../eph/2018VN2.csv
# Save ephemeris: ../eph/2018V4.csv
# Save ephemeris: ../eph/2018V5.csv
# Save ephemeris: ../eph/2018W1.csv
# Save ephemeris: ../eph/2018W2.csv
# Save ephemeris: ../eph/2018X2.csv
# Save ephemeris: ../eph/2018X3.csv
# Save ephemeris: ../eph/2018Y1.csv
# Save ephemeris: ../eph/2018Y2.csv
# Save ephemeris: ../eph/2019A1.csv
# Save ephemeris: ../eph/2019A2.csv
# Save ephemeris: ../eph/2019A3.csv
# Save ephemeris: ../eph/2019A4.csv
# Save ephemeris: ../eph/2019A5.csv
# Save ephemeris: ../eph/2019A6.csv
# Save ephemeris: ../eph/2019A9.csv
# Save ephemeris: ../eph/2019B1.csv
# Save ephemeris: ../eph/2019B2.csv
# Save ephemeris: ../eph/2019B3.csv
# Save ephemeris: ../eph/2019C1.csv
# Save ephemeris: ../eph/2019D1.csv
# Save ephemeris: ../eph/2019E3.csv
# Save ephemeris: ../eph/2019F1.csv
# Save ephemeris: ../eph/2019F2.csv
# Save ephemeris: ../eph/2019G2.csv
# Save ephemeris: ../eph/2019G4.csv
# Save ephemeris: ../eph/2019GG21.csv
# Save ephemeris: ../eph/2019H1.csv
# Save ephemeris: ../eph/2019J1.csv
# Save ephemeris: ../eph/2019J2.csv
# Save ephemeris: ../eph/2019J3.csv
# Save ephemeris: ../eph/2019JU6.csv
# Save ephemeris: ../eph/2019K1.csv
# Save ephemeris: ../eph/2019K4.csv
# Save ephemeris: ../eph/2019K5.csv
# Save ephemeris: ../eph/2019K6.csv
# Save ephemeris: ../eph/2019K7.csv
# Save ephemeris: ../eph/2019K8.csv
# Save ephemeris: ../eph/2019L1.csv
# Save ephemeris: ../eph/2019L2.csv
# Save ephemeris: ../eph/2019LD2.csv
# Save ephemeris: ../eph/2019L3.csv
# Save ephemeris: ../eph/2019LM4.csv
# Save ephemeris: ../eph/2019LB7.csv
# Save ephemeris: ../eph/2019M3.csv
# Save ephemeris: ../eph/2019M4.csv
# Save ephemeris: ../eph/2019N1.csv
# Save ephemeris: ../eph/2019NJ3.csv
# Save ephemeris: ../eph/2019O2.csv
# Save ephemeris: ../eph/2019O3.csv
# Save ephemeris: ../eph/2019Q1.csv
# Save ephemeris: ../eph/2019Q3.csv
# Save ephemeris: ../eph/2019Q4.csv
# Save ephemeris: ../eph/2019S2.csv
# Save ephemeris: ../eph/2019S3.csv
# Save ephemeris: ../eph/2019S4.csv
# Save ephemeris: ../eph/2019T2.csv
# Save ephemeris: ../eph/2019T3.csv
# Save ephemeris: ../eph/2019T4.csv
# Save ephemeris: ../eph/2019T5.csv
# Save ephemeris: ../eph/2019T6.csv
# Save ephemeris: ../eph/2019U4.csv
# Save ephemeris: ../eph/2019U5.csv
# Save ephemeris: ../eph/2019U6.csv
# Save ephemeris: ../eph/2019V1.csv
# Save ephemeris: ../eph/2019V2.csv
# Save ephemeris: ../eph/2019W1.csv
# Save ephemeris: ../eph/2019X1.csv
# Save ephemeris: ../eph/2019X2.csv
# Save ephemeris: ../eph/2019Y1.csv
# 2025-09-26 14:40:42,191 [INFO] Non-unique id for '2019 Y4'. Retrying with record #90004576 ...
# Save ephemeris: ../eph/2019Y4.csv
# Save ephemeris: ../eph/2019Y5.csv
# Save ephemeris: ../eph/2020A2.csv
# Save ephemeris: ../eph/2020A3.csv
# Save ephemeris: ../eph/2020A4.csv
# Save ephemeris: ../eph/2020B2.csv
# Save ephemeris: ../eph/2020B3.csv
# Save ephemeris: ../eph/2020B4.csv
# Save ephemeris: ../eph/2020F2.csv
# Save ephemeris: ../eph/2020F3.csv
# Save ephemeris: ../eph/2020F5.csv
# Save ephemeris: ../eph/2020F6.csv
# Save ephemeris: ../eph/2020F7.csv
# Save ephemeris: ../eph/2020F8.csv
# Save ephemeris: ../eph/2020G1.csv
# Save ephemeris: ../eph/2020H2.csv
# Save ephemeris: ../eph/2020H3.csv
# Save ephemeris: ../eph/2020H4.csv
# Save ephemeris: ../eph/2020H5.csv
# Save ephemeris: ../eph/2020H6.csv
# Save ephemeris: ../eph/2020H7.csv
# Save ephemeris: ../eph/2020H8.csv
# Save ephemeris: ../eph/2020H11.csv
# Save ephemeris: ../eph/2020J1.csv
# Save ephemeris: ../eph/2020K1.csv
# Save ephemeris: ../eph/2020K2.csv
# Save ephemeris: ../eph/2020K3.csv
# Save ephemeris: ../eph/2020K4.csv
# Save ephemeris: ../eph/2020K5.csv
# Save ephemeris: ../eph/2020K6.csv
# Save ephemeris: ../eph/2020K7.csv
# Save ephemeris: ../eph/2020K8.csv
# Save ephemeris: ../eph/2020K9.csv
# Save ephemeris: ../eph/2020M1.csv
# Save ephemeris: ../eph/2020M3.csv
# Save ephemeris: ../eph/2020MK4.csv
# Save ephemeris: ../eph/2020M5.csv
# Save ephemeris: ../eph/2020N1.csv
# Save ephemeris: ../eph/2020N2.csv
# Save ephemeris: ../eph/2020O2.csv
# Save ephemeris: ../eph/2020O3.csv
# Save ephemeris: ../eph/2020P1.csv
# Save ephemeris: ../eph/2020P3.csv
# Save ephemeris: ../eph/2020PV6.csv
# Save ephemeris: ../eph/2020Q1.csv
# Save ephemeris: ../eph/2020Q2.csv
# Save ephemeris: ../eph/2020R2.csv
# Save ephemeris: ../eph/2020R4.csv
# Save ephemeris: ../eph/2020R5.csv
# Save ephemeris: ../eph/2020R6.csv
# Save ephemeris: ../eph/2020R7.csv
# Save ephemeris: ../eph/2020S1.csv
# Save ephemeris: ../eph/2020S2.csv
# Save ephemeris: ../eph/2020S3.csv
# Save ephemeris: ../eph/2020S4.csv
# Save ephemeris: ../eph/2020S5.csv
# Save ephemeris: ../eph/2020S7.csv
# Save ephemeris: ../eph/2020S8.csv
# Save ephemeris: ../eph/2020T2.csv
# Save ephemeris: ../eph/2020T3.csv
# Save ephemeris: ../eph/2020T4.csv
# Save ephemeris: ../eph/2020T5.csv
# Save ephemeris: ../eph/2020U2.csv
# Save ephemeris: ../eph/2020U3.csv
# Save ephemeris: ../eph/2020U4.csv
# Save ephemeris: ../eph/2020U5.csv
# Save ephemeris: ../eph/2020V2.csv
# Save ephemeris: ../eph/2020V3.csv
# Save ephemeris: ../eph/2020V4.csv
# Save ephemeris: ../eph/2020W1.csv
# Save ephemeris: ../eph/2020W5.csv
# Save ephemeris: ../eph/2020WJ5.csv
# Save ephemeris: ../eph/2020X1.csv
# Save ephemeris: ../eph/2020X2.csv
# Save ephemeris: ../eph/2020X4.csv
# Save ephemeris: ../eph/2020Y2.csv
# Save ephemeris: ../eph/2020Y3.csv
# Save ephemeris: ../eph/2021A1.csv
# Save ephemeris: ../eph/2021A2.csv
# Save ephemeris: ../eph/2021A4.csv
# Save ephemeris: ../eph/2021A5.csv
# Save ephemeris: ../eph/2021A6.csv
# Save ephemeris: ../eph/2021A7.csv
# Save ephemeris: ../eph/2021A9.csv
# Save ephemeris: ../eph/2021A10.csv
# Save ephemeris: ../eph/2021B2.csv
# Save ephemeris: ../eph/2021B3.csv
# Save ephemeris: ../eph/2021C1.csv
# Save ephemeris: ../eph/2021C2.csv
# Save ephemeris: ../eph/2021C3.csv
# Save ephemeris: ../eph/2021C4.csv
# Save ephemeris: ../eph/2021C5.csv
# Save ephemeris: ../eph/2021C6.csv
# Save ephemeris: ../eph/2021D1.csv
# Save ephemeris: ../eph/2021D2.csv
# Save ephemeris: ../eph/2021E3.csv
# Save ephemeris: ../eph/2021F1.csv
# Save ephemeris: ../eph/2021G1.csv
# Save ephemeris: ../eph/2021G2.csv
# Save ephemeris: ../eph/2021G3.csv
# Save ephemeris: ../eph/2021HS.csv
# Save ephemeris: ../eph/2021J1.csv
# Save ephemeris: ../eph/2021J2.csv
# Save ephemeris: ../eph/2021J3.csv
# Save ephemeris: ../eph/2021K1.csv
# Save ephemeris: ../eph/2021K2.csv
# Save ephemeris: ../eph/2021K3.csv
# Save ephemeris: ../eph/2021L2.csv
# Save ephemeris: ../eph/2021L3.csv
# Save ephemeris: ../eph/2021N1.csv
# Save ephemeris: ../eph/2021N2.csv
# Save ephemeris: ../eph/2021N3.csv
# Save ephemeris: ../eph/2021O1.csv
# Save ephemeris: ../eph/2021O3.csv
# Save ephemeris: ../eph/2021P1.csv
# Save ephemeris: ../eph/2021P2.csv
# Save ephemeris: ../eph/2021P3.csv
# Save ephemeris: ../eph/2021P4.csv
# Save ephemeris: ../eph/2021PE20.csv
# Save ephemeris: ../eph/2021Q3.csv
# Save ephemeris: ../eph/2021Q4.csv
# Save ephemeris: ../eph/2021Q5.csv
# Save ephemeris: ../eph/2021Q6.csv
# Save ephemeris: ../eph/2021QM45.csv
# Save ephemeris: ../eph/2021R1.csv
# Save ephemeris: ../eph/2021R2.csv
# Save ephemeris: ../eph/2021R3.csv
# Save ephemeris: ../eph/2021R4.csv
# Save ephemeris: ../eph/2021R5.csv
# Save ephemeris: ../eph/2021R6.csv
# Save ephemeris: ../eph/2021R7.csv
# Save ephemeris: ../eph/2021R8.csv
# Save ephemeris: ../eph/2021S1.csv
# Save ephemeris: ../eph/2021S3.csv
# Save ephemeris: ../eph/2021S4.csv
# Save ephemeris: ../eph/2021T1.csv
# Save ephemeris: ../eph/2021T2.csv
# Save ephemeris: ../eph/2021T4.csv
# Save ephemeris: ../eph/2021TR81.csv
# Save ephemeris: ../eph/2021U1.csv
# Save ephemeris: ../eph/2021U3.csv
# Save ephemeris: ../eph/2021U4.csv
# Save ephemeris: ../eph/2021U5.csv
# Save ephemeris: ../eph/2021V1.csv
# Save ephemeris: ../eph/2021V2.csv
# Save ephemeris: ../eph/2021X1.csv
# Save ephemeris: ../eph/2021X2.csv
# Save ephemeris: ../eph/2021Y1.csv
# Save ephemeris: ../eph/2022A1.csv
# Save ephemeris: ../eph/2022A2.csv
# Save ephemeris: ../eph/2022A3.csv
# Save ephemeris: ../eph/2022B1.csv
# Save ephemeris: ../eph/2022B4.csv
# Save ephemeris: ../eph/2022BV9.csv
# Save ephemeris: ../eph/2022C1.csv
# Save ephemeris: ../eph/2022C2.csv
# Save ephemeris: ../eph/2022C3.csv
# Save ephemeris: ../eph/2022D1.csv
# Save ephemeris: ../eph/2022D2.csv
# Save ephemeris: ../eph/2022E2.csv
# Save ephemeris: ../eph/2022E3.csv
# Save ephemeris: ../eph/2022F1.csv
# Save ephemeris: ../eph/2022F2.csv
# Save ephemeris: ../eph/2022H1.csv
# Save ephemeris: ../eph/2022J1.csv
# Save ephemeris: ../eph/2022J2.csv
# Save ephemeris: ../eph/2022JK5.csv
# Save ephemeris: ../eph/2022K1.csv
# Save ephemeris: ../eph/2022L1.csv
# Save ephemeris: ../eph/2022L2.csv
# Save ephemeris: ../eph/2022L3.csv
# Save ephemeris: ../eph/2022L4.csv
# Save ephemeris: ../eph/2022N1.csv
# Save ephemeris: ../eph/2022N2.csv
# Save ephemeris: ../eph/2022O1.csv
# Save ephemeris: ../eph/2022O2.csv
# Save ephemeris: ../eph/2022P1.csv
# Save ephemeris: ../eph/2022P2.csv
# Save ephemeris: ../eph/2022P3.csv
# Save ephemeris: ../eph/2022Q2.csv
# Save ephemeris: ../eph/2022QE78.csv
# Save ephemeris: ../eph/2022R1.csv
# Save ephemeris: ../eph/2022R2.csv
# Save ephemeris: ../eph/2022R3.csv
# Save ephemeris: ../eph/2022R4.csv
# Save ephemeris: ../eph/2022R5.csv
# Save ephemeris: ../eph/2022R6.csv
# Save ephemeris: ../eph/2022S1.csv
# Save ephemeris: ../eph/2022S3.csv
# Save ephemeris: ../eph/2022S4.csv
# Save ephemeris: ../eph/2022S5.csv
# Save ephemeris: ../eph/2022T1.csv
# Save ephemeris: ../eph/2022U1.csv
# Save ephemeris: ../eph/2022U2.csv
# Save ephemeris: ../eph/2022U3.csv
# Save ephemeris: ../eph/2022U4.csv
# Save ephemeris: ../eph/2022V2.csv
# Save ephemeris: ../eph/2022W1.csv
# Save ephemeris: ../eph/2022W2.csv
# Save ephemeris: ../eph/2022W3.csv
# Save ephemeris: ../eph/2022Y1.csv
# Save ephemeris: ../eph/2022Y2.csv
# Save ephemeris: ../eph/2023A1.csv
# Save ephemeris: ../eph/2023A2.csv
# Save ephemeris: ../eph/2023A3.csv
# Save ephemeris: ../eph/2023B1.csv
# Save ephemeris: ../eph/2023B2.csv
# Save ephemeris: ../eph/2023B3.csv
# Save ephemeris: ../eph/2023C2.csv
# Save ephemeris: ../eph/2023E1.csv
# Save ephemeris: ../eph/2023F1.csv
# Save ephemeris: ../eph/2023F2.csv
# Save ephemeris: ../eph/2023F3.csv
# Save ephemeris: ../eph/2023H1.csv
# Save ephemeris: ../eph/2023H2.csv
# Save ephemeris: ../eph/2023H3.csv
# Save ephemeris: ../eph/2023H5.csv
# Save ephemeris: ../eph/2023JN16.csv
# Save ephemeris: ../eph/2023K1.csv
# Save ephemeris: ../eph/2023M1.csv
# Save ephemeris: ../eph/2023M2.csv
# Save ephemeris: ../eph/2023M4.csv
# Save ephemeris: ../eph/2023P1.csv
# Save ephemeris: ../eph/2023Q1.csv
# Save ephemeris: ../eph/2023Q2.csv
# Save ephemeris: ../eph/2023R1.csv
# Save ephemeris: ../eph/2023R2.csv
# Save ephemeris: ../eph/2023RN3.csv
# Save ephemeris: ../eph/2023RS61.csv
# Save ephemeris: ../eph/2023S1.csv
# Save ephemeris: ../eph/2023S2.csv
# Save ephemeris: ../eph/2023S3.csv
# Save ephemeris: ../eph/2023T1.csv
# Save ephemeris: ../eph/2023T2.csv
# Save ephemeris: ../eph/2023T3.csv
# Save ephemeris: ../eph/2023TD22.csv
# Save ephemeris: ../eph/2023U1.csv
# Save ephemeris: ../eph/2023V1.csv
# Save ephemeris: ../eph/2023V2.csv
# Save ephemeris: ../eph/2023V3.csv
# Save ephemeris: ../eph/2023V4.csv
# Save ephemeris: ../eph/2023V5.csv
# Save ephemeris: ../eph/2023V6.csv
# Save ephemeris: ../eph/2023X1.csv
# Save ephemeris: ../eph/2023X2.csv
# Save ephemeris: ../eph/2023X3.csv
# Save ephemeris: ../eph/2023X4.csv
# Save ephemeris: ../eph/2023X7.csv
# Save ephemeris: ../eph/2023Y1.csv
# Save ephemeris: ../eph/2023Y2.csv
# Save ephemeris: ../eph/2024A1.csv
# Save ephemeris: ../eph/2024A2.csv
# Save ephemeris: ../eph/2024B1.csv
# Save ephemeris: ../eph/2024B2.csv
# Save ephemeris: ../eph/2024C1.csv
# Save ephemeris: ../eph/2024C2.csv
# Save ephemeris: ../eph/2024C3.csv
# Save ephemeris: ../eph/2024C4.csv
# Save ephemeris: ../eph/2024D1.csv
# Save ephemeris: ../eph/2024E1.csv
# Save ephemeris: ../eph/2024E2.csv
# Save ephemeris: ../eph/2024F1.csv
# Save ephemeris: ../eph/2024F2.csv
# Save ephemeris: ../eph/2024FG9.csv
# Save ephemeris: ../eph/2024G1.csv
# Save ephemeris: ../eph/2024G2.csv
# Save ephemeris: ../eph/2024G3.csv
# Save ephemeris: ../eph/2024G4.csv
# Save ephemeris: ../eph/2024G5.csv
# Save ephemeris: ../eph/2024G6.csv
# Save ephemeris: ../eph/2024G7.csv
# Save ephemeris: ../eph/2024J1.csv
# Save ephemeris: ../eph/2024J2.csv
# Save ephemeris: ../eph/2024J3.csv
# Save ephemeris: ../eph/2024J4.csv
# Save ephemeris: ../eph/2024K1.csv
# Save ephemeris: ../eph/2024L1.csv
# Save ephemeris: ../eph/2024L2.csv
# Save ephemeris: ../eph/2024L3.csv
# Save ephemeris: ../eph/2024L5.csv
# Save ephemeris: ../eph/2024M1.csv
# Save ephemeris: ../eph/2024N1.csv
# Save ephemeris: ../eph/2024N3.csv
# Save ephemeris: ../eph/2024N4.csv
# Save ephemeris: ../eph/2024O1.csv
# Save ephemeris: ../eph/2024O2.csv
# Save ephemeris: ../eph/2024OC2.csv
# Save ephemeris: ../eph/2024PN7.csv
# Save ephemeris: ../eph/2024Q1.csv
# Save ephemeris: ../eph/2024Q3.csv
# Save ephemeris: ../eph/2024Q4.csv
# Save ephemeris: ../eph/2024R1.csv
# Save ephemeris: ../eph/2024R2.csv
# Save ephemeris: ../eph/2024R3.csv
# Save ephemeris: ../eph/2024R4.csv
# Save ephemeris: ../eph/2024S1.csv
# Save ephemeris: ../eph/2024S2.csv
# Save ephemeris: ../eph/2024T1.csv
# Save ephemeris: ../eph/2024T2.csv
# Save ephemeris: ../eph/2024T3.csv
# Save ephemeris: ../eph/2024T5.csv
# Save ephemeris: ../eph/2024U1.csv
# Save ephemeris: ../eph/2024V1.csv
# Save ephemeris: ../eph/2024V2.csv
# Save ephemeris: ../eph/2024W1.csv
# Save ephemeris: ../eph/2024X1.csv
# Save ephemeris: ../eph/2024X2.csv
# Save ephemeris: ../eph/2024X3.csv
# Save ephemeris: ../eph/2024X4.csv
# Save ephemeris: ../eph/2024XK14.csv
# Save ephemeris: ../eph/2024Y1.csv
# Save ephemeris: ../eph/2025A2.csv
# Save ephemeris: ../eph/2025A3.csv
# Save ephemeris: ../eph/2025A4.csv
# Save ephemeris: ../eph/2025A6.csv
# Save ephemeris: ../eph/2025B1.csv
# Save ephemeris: ../eph/2025B2.csv
# Save ephemeris: ../eph/2025C1.csv
# Save ephemeris: ../eph/2025D1.csv
# Save ephemeris: ../eph/2025D2.csv
# Save ephemeris: ../eph/2025D3.csv
# Save ephemeris: ../eph/2025D4.csv
# Save ephemeris: ../eph/2025D5.csv
# Save ephemeris: ../eph/2025D6.csv
# Save ephemeris: ../eph/2025E1.csv
# Save ephemeris: ../eph/2025F1.csv
# Save ephemeris: ../eph/2025F2.csv
# Save ephemeris: ../eph/2025J1.csv
# Save ephemeris: ../eph/2025K1.csv
# Save ephemeris: ../eph/2025K2.csv
# Save ephemeris: ../eph/2025K3.csv
# Save ephemeris: ../eph/2025K4.csv
# Save ephemeris: ../eph/2025L1.csv
# Save ephemeris: ../eph/2025L2.csv
# Save ephemeris: ../eph/2025M1.csv
# Save ephemeris: ../eph/2025M2.csv
# Save ephemeris: ../eph/2025M3.csv
# Save ephemeris: ../eph/2025N1.csv
# Save ephemeris: ../eph/2025N2.csv
# Save ephemeris: ../eph/2025O2.csv
# Save ephemeris: ../eph/2025Q1.csv
# Save ephemeris: ../eph/2025Q2.csv
# Save ephemeris: ../eph/2025R1.csv
# Save ephemeris: ../eph/2025R2.csv
# Save ephemeris: ../eph/2025R3.csv
