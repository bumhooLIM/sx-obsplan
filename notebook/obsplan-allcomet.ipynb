# %%
import sxobsplan

from pathlib import Path
import pandas as pd
import astropy.units as u
from astropy.time import Time
from astropy.coordinates import EarthLocation

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from mpl_toolkits.axes_grid1 import make_axes_locatable
import _rcparams

# %%
# SBDB
fpath_sbdb = Path("../data/sbdb_query_results_comet_ver260105.csv") # SBDB comet query results (latest ver)
df_sbdb = pd.read_csv(fpath_sbdb)
df_sbdb.head()
# Out:
#      spkid       full_name pdes     name prefix  neo  pha  sats   H   G  ...  \
# 0  1000036       1P/Halley   1P   Halley      P    Y  NaN     0 NaN NaN  ...
# 1  1000025        2P/Encke   2P    Encke      P    Y  NaN     0 NaN NaN  ...
# 2  1000504        3D/Biela   3D    Biela      D    Y  NaN     0 NaN NaN  ...
# 3  1000026         4P/Faye   4P     Faye      P  NaN  NaN     0 NaN NaN  ...
# 4  1000505      5D/Brorsen   5D  Brorsen      D    Y  NaN     0 NaN NaN  ...
#
#        rms  two_body            A1      A1_sigma            A2      A2_sigma  \
# 0  0.61032       NaN  4.900000e-10  4.000000e-11  1.600000e-10  4.600000e-15
# 1  0.44859       NaN  2.300000e-10  6.100000e-11 -6.500000e-13  4.000000e-12
# 2      NaN       NaN  3.900000e-09           NaN -2.500000e-10           NaN
# 3  0.54329       NaN  4.000000e-09  1.200000e-10  3.200000e-10  6.300000e-11
# 4      NaN       NaN  1.300000e-08           NaN  1.300000e-09           NaN
#
#              A3      A3_sigma    DT  DT_sigma
# 0           NaN           NaN   NaN       NaN
# 1           NaN           NaN   NaN       NaN
# 2           NaN           NaN   NaN       NaN
# 3 -7.100000e-10  4.200000e-11 -37.7      2.17
# 4           NaN           NaN   NaN       NaN
#
# [5 rows x 79 columns]

# %%
df_sbdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3878 entries, 0 to 3877
# Data columns (total 79 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   spkid           3878 non-null   int64
#  1   full_name       3878 non-null   object
#  2   pdes            3878 non-null   object
#  3   name            3769 non-null   object
#  4   prefix          3878 non-null   object
#  5   neo             124 non-null    object
#  6   pha             0 non-null      float64
#  7   sats            3878 non-null   int64
#  8   H               1 non-null      float64
#  9   G               0 non-null      float64
#  10  M1              1867 non-null   float64
#  11  M2              826 non-null    float64
#  12  K1              1867 non-null   float64
#  13  K2              826 non-null    float64
#  14  PC              819 non-null    float64
#  15  diameter        103 non-null    float64
#  16  extent          2 non-null      object
#  17  albedo          19 non-null     float64
#  18  rot_per         23 non-null     float64
#  19  GM              1 non-null      float64
#  20  BV              0 non-null      float64
#  21  UB              0 non-null      float64
#  22  IR              0 non-null      float64
#  23  spec_B          0 non-null      float64
#  24  spec_T          0 non-null      float64
#  25  H_sigma         0 non-null      float64
#  26  diameter_sigma  14 non-null     float64
#  27  orbit_id        3878 non-null   object
#  28  epoch           3878 non-null   float64
#  29  epoch_mjd       3878 non-null   int64
#  30  epoch_cal       3878 non-null   object
#  31  equinox         3878 non-null   object
#  32  e               3878 non-null   float64
#  33  a               2119 non-null   float64
#  34  q               3878 non-null   float64
#  35  i               3878 non-null   float64
#  36  om              3878 non-null   float64
#  37  w               3878 non-null   float64
#  38  ma              2119 non-null   float64
#  39  ad              1624 non-null   float64
#  40  n               2119 non-null   float64
#  41  tp              3878 non-null   float64
#  42  tp_cal          3878 non-null   object
#  43  per             1570 non-null   float64
#  44  per_y           1570 non-null   float64
#  45  moid            2059 non-null   float64
#  46  moid_ld         2059 non-null   float64
#  47  moid_jup        2044 non-null   float64
#  48  t_jup           1748 non-null   float64
#  49  sigma_e         2055 non-null   float64
#  50  sigma_a         2017 non-null   float64
#  51  sigma_q         2055 non-null   float64
#  52  sigma_i         2055 non-null   float64
#  53  sigma_om        2055 non-null   float64
#  54  sigma_w         2055 non-null   float64
#  55  sigma_ma        2017 non-null   float64
#  56  sigma_ad        1545 non-null   float64
#  57  sigma_n         2017 non-null   float64
#  58  sigma_tp        2055 non-null   float64
#  59  sigma_per       1545 non-null   float64
#  60  class           3878 non-null   object
#  61  producer        2401 non-null   object
#  62  data_arc        3869 non-null   float64
#  63  first_obs       3875 non-null   object
#  64  last_obs        3875 non-null   object
#  65  n_obs_used      3829 non-null   float64
#  66  n_del_obs_used  7 non-null      float64
#  67  n_dop_obs_used  7 non-null      float64
#  68  condition_code  1010 non-null   float64
#  69  rms             2054 non-null   float64
#  70  two_body        1920 non-null   object
#  71  A1              256 non-null    float64
#  72  A1_sigma        253 non-null    float64
#  73  A2              329 non-null    float64
#  74  A2_sigma        326 non-null    float64
#  75  A3              109 non-null    float64
#  76  A3_sigma        108 non-null    float64
#  77  DT              37 non-null     float64
#  78  DT_sigma        36 non-null     float64
# dtypes: float64(61), int64(3), object(15)
# memory usage: 2.3+ MB

# %%
# Ephemeris
EPHDIR = Path("../eph")

# %%
# Observatory locations

# LSGT (Siding Spring Observatory, Australia)
siding_spring_obs = EarthLocation(
    lon=149.0644 * u.deg,  # (149° 03' 52" E)
    lat=-31.2733 * u.deg,  # (31° 16' 24" S)
    height=1165 * u.m
)

# 7DT (el Sauce Observatory, Chile)
el_sauce_obs = EarthLocation(
    lon=-70.763 * u.deg,
    lat=-30.4725 * u.deg,
    height=1600 * u.m
)

# LOAO (Mount Lemmon Observatory, USA)
lemmon_obs = EarthLocation(
    lon=-110.7893 * u.deg,
    lat=32.4420 * u.deg,
    height=2791 * u.m
)

dict_observatory = {
    "gemini_north": "gemini_north",
    "gemini_south": "gemini_south",
    "lemmon"      : lemmon_obs,
    "lsgt"        : siding_spring_obs,
    "sevendt"     : el_sauce_obs
}

for obsname in dict_observatory:
    print(obsname)
    print(sxobsplan.resolve_location(dict_observatory[obsname]))
# Out:
# gemini_north
# (-5464283.965730824, -2493783.6435031025, 2150785.9062398607) m
# gemini_south
# (1820193.0684460273, -5208343.034275673, -3194842.5004834323) m
# lemmon
# (-1913184.9927148158, -5039329.780596793, 3403394.0181447067) m
# lsgt
# (-4680991.411618329, 2805467.2896081726, -3292434.228573915) m
# sevendt
# (1813194.1454216233, -5195977.984234542, -3216438.7522559315) m

# %%
VISDIR = Path("../visibility_ver260105_allcomet")
VISDIR.mkdir(exist_ok=True, parents=True)

for idx, row in df_sbdb.iterrows():

    pdes = row.pdes
    fpath_eph = EPHDIR / f"{''.join(pdes.split())}.csv"
    fpath_vis = VISDIR / f"{''.join(pdes.split())}.csv"

    if not fpath_eph.exists():
        print(f"{fpath_eph.name} does not exists. Skip the rows.")
        continue

    # target info.
    target = df_sbdb[df_sbdb["pdes"] == pdes].iloc[0]

    # ephemeris info.
    eph = pd.read_csv(fpath_eph)

    # Skip if all eph.r > 9 or all eph.Tmag > 22
    if (eph.r > 10).all() or (eph.Tmag > 22).all():
        print(f"{fpath_eph.name}: all r > 9 or all Tmag > 22. Skip the rows.")
        continue

    # Visibility
    df_visible = pd.DataFrame()

    for idx, row in eph.iterrows():

        df_visible.at[idx, "pdes"] = target["pdes"]
        df_visible.at[idx, "full_name"] = target["full_name"]
        df_visible.at[idx, "name"] = target["name"]
        df_visible.at[idx, "class"] = target["class"].upper()

        df_visible.at[idx, "datetime_jd"] = row.datetime_jd
        df_visible.at[idx, "ra"] = row.RA
        df_visible.at[idx, "dec"] = row.DEC
        df_visible.at[idx, "r"] = row.r
        df_visible.at[idx, "delta"] = row.delta
        df_visible.at[idx, "tmag"] = row.Tmag
        df_visible.at[idx, "elong"] = row.elong
        df_visible.at[idx, "lunar_elong"] = row.lunar_elong
        df_visible.at[idx, "glxlat"] = row.GlxLat
        df_visible.at[idx, "alpha"] = row.alpha
        
        for observatory, location in dict_observatory.items():

            is_visible, blocks = sxobsplan.is_target_visible(
                ra=row.RA*u.deg, dec=row.DEC*u.deg, date=Time(row.datetime_jd, format="jd"),
                location=location,
                elev_min=30*u.deg, duration=1*u.hour
            )

            df_visible.at[idx, f"is_visible_{observatory}"] = is_visible

            if is_visible:
                df_visible.at[idx, f"duration_{observatory}"] = blocks[0]["duration"].to_value("hour")
            else:
                df_visible.at[idx, f"duration_{observatory}"] = None

    df_visible.to_csv(fpath_vis)
    print(f"Visibility saved. {fpath_vis}")
# Out:
# 1P.csv: all r > 9 or all Tmag > 22. Skip the rows.
# Visibility saved. ../visibility_ver260105_comet/2P.csv
# 3D.csv does not exists. Skip the rows.
# Visibility saved. ../visibility_ver260105_comet/4P.csv
# 5D.csv does not exists. Skip the rows.
# Visibility saved. ../visibility_ver260105_comet/6P.csv
# Visibility saved. ../visibility_ver260105_comet/7P.csv
# 8P.csv: all r > 9 or all Tmag > 22. Skip the rows.
# Visibility saved. ../visibility_ver260105_comet/9P.csv
# Visibility saved. ../visibility_ver260105_comet/10P.csv
# Visibility saved. ../visibility_ver260105_comet/11P.csv
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 61
#      58         else:
#      59             df_visible.at[idx, f"duration_{observatory}"] = None
# ---> 61 df_visible.to_csv(fpath_vis)
#      62 print(f"Visibility saved. {fpath_vis}")
#
# File ~/miniconda3/envs/spherex/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/spherex/lib/python3.10/site-packages/pandas/core/generic.py:3986, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3975 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3977 formatter = DataFrameFormatter(
#    3978     frame=df,
#    3979     header=header,
#    (...)
#    3983     decimal=decimal,
#    3984 )
# -> 3986 return DataFrameRenderer(formatter).to_csv(
#    3987     path_or_buf,
#    3988     lineterminator=lineterminator,
#    3989     sep=sep,
#    3990     encoding=encoding,
#    3991     errors=errors,
#    3992     compression=compression,
#    3993     quoting=quoting,
#    3994     columns=columns,
#    3995     index_label=index_label,
#    3996     mode=mode,
#    3997     chunksize=chunksize,
#    3998     quotechar=quotechar,
#    3999     date_format=date_format,
#    4000     doublequote=doublequote,
#    4001     escapechar=escapechar,
#    4002     storage_options=storage_options,
#    4003 )
#
# File ~/miniconda3/envs/spherex/lib/python3.10/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/miniconda3/envs/spherex/lib/python3.10/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/miniconda3/envs/spherex/lib/python3.10/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/miniconda3/envs/spherex/lib/python3.10/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '../visibility_ver260105_comet'

# %%
FIGDIR = Path("../fig")
FIGDIR.mkdir(exist_ok=True, parents=True)

for idx, row in df_sbdb.iterrows():

    pdes = row.pdes
    
    fpath_eph = EPHDIR/f"{''.join(pdes.split())}.csv"
    fpath_vis = VISDIR/f"{''.join(pdes.split())}.csv"
    fpath_fig = FIGDIR/f"{''.join(pdes.split())}.png"
    if not fpath_vis.exists():
        print(f"{fpath_vis.name} does not exists. Skip the rows.")
        continue

    df_visible = pd.read_csv(fpath_vis)
    eph = pd.read_csv(fpath_eph)

    # SPHEREX window (80 < e < 110)
    mask_sx = (eph.elong > 80) & (eph.elong < 110)

    fig = plt.figure(figsize=(15, 3))
    ax = fig.add_subplot()

    date_list = pd.to_datetime(df_visible.datetime_jd, unit="D", origin="julian")

    sc_r  = ax.scatter(date_list, [1]*len(date_list), c=eph.r, cmap="jet_r", marker="s", vmin=1, vmax=9)
    sc_v  = ax.scatter(date_list, [2]*len(date_list), c=eph.Tmag, cmap="gray", marker="s", vmin=16, vmax=22)
    ax.axhline(y=3, color="k", linestyle=":")
    sc_sx = ax.scatter(date_list[mask_sx], [4]*sum(mask_sx), c="C3", marker="s")
    observatories = {
        "gemini_north": {"yloc": 5, "color": "C4"},
        "gemini_south": {"yloc": 6, "color": "C5"},
    }
    for observatory, props in observatories.items():
        mask_visible = df_visible[f"is_visible_{observatory}"]
        ax.scatter(date_list[mask_visible], [props["yloc"]]*sum(mask_visible), 
                c=props["color"], marker="s")

    yticks = [1, 2, 4, 5, 6]
    yticklabels = [
        r"$R_\mathrm{h}$ (au)",
        r"$V_\mathrm{mag}$",
        "SPHEREx Window",
        "Gemini North",
        "Gemini South"
    ]
    ax.set_yticks(yticks)
    ax.set_yticklabels(yticklabels)
    ax.set_title(f"{eph['targetname'].iloc[0]}")

    # Colorbars
    divider = make_axes_locatable(ax)
    cax_r = divider.append_axes("right", size="2%", pad=0.2)
    cax_v = divider.append_axes("right", size="2%", pad=0.3)
    cb_r = plt.colorbar(sc_r, cax=cax_r, orientation="vertical")
    # cb_r.set_label(r"$R_\mathrm{h}$ [au]")
    cb_v = plt.colorbar(sc_v, cax=cax_v, orientation="vertical")
    # cb_v.set_label(r"$V_\mathrm{mag}$")

    ax.set_xlim(date_list.min(), date_list.max()+pd.Timedelta(days=5))
    ax.set_ylim(7, 0)
    ax.xaxis.set_minor_locator(mdates.MonthLocator())
    ax.grid(True, axis="x", which="major", linestyle="--", alpha=0.5)
    ax.grid(True, axis="x", which="minor", linestyle=":", alpha=0.3)

    plt.savefig(fpath_fig)
    print(f"Figure saved: {fpath_fig}")
    plt.close()
# Out:
# 1P.csv does not exists. Skip the rows.
# Figure saved: ../fig/2P.png
# 3D.csv does not exists. Skip the rows.
# Figure saved: ../fig/4P.png
# 5D.csv does not exists. Skip the rows.
# Figure saved: ../fig/6P.png
# Figure saved: ../fig/7P.png
# 8P.csv does not exists. Skip the rows.
# Figure saved: ../fig/9P.png
# Figure saved: ../fig/10P.png
# Figure saved: ../fig/11P.png
# Figure saved: ../fig/12P.png
# Figure saved: ../fig/13P.png
# Figure saved: ../fig/14P.png
# Figure saved: ../fig/15P.png
# Figure saved: ../fig/16P.png
# Figure saved: ../fig/17P.png
# 18D.csv does not exists. Skip the rows.
# Figure saved: ../fig/19P.png
# 20D.csv does not exists. Skip the rows.
# Figure saved: ../fig/21P.png
# Figure saved: ../fig/22P.png
# 23P.csv does not exists. Skip the rows.
# Figure saved: ../fig/24P.png
# 25D.csv does not exists. Skip the rows.
# Figure saved: ../fig/26P.png
# 27P.csv does not exists. Skip the rows.
# Figure saved: ../fig/28P.png
# Figure saved: ../fig/29P.png
# Figure saved: ../fig/30P.png
# Figure saved: ../fig/31P.png
# Figure saved: ../fig/32P.png
# Figure saved: ../fig/33P.png
# 34D.csv does not exists. Skip the rows.
# 35P.csv does not exists. Skip the rows.
# Figure saved: ../fig/36P.png
# Figure saved: ../fig/37P.png
# 38P.csv does not exists. Skip the rows.
# Figure saved: ../fig/39P.png
# Figure saved: ../fig/40P.png
# Figure saved: ../fig/41P.png
# Figure saved: ../fig/42P.png
# Figure saved: ../fig/43P.png
# Figure saved: ../fig/44P.png
# Figure saved: ../fig/45P.png
# Figure saved: ../fig/46P.png
# Figure saved: ../fig/47P.png
# Figure saved: ../fig/48P.png
# Figure saved: ../fig/49P.png
# Figure saved: ../fig/50P.png
# 51P.csv does not exists. Skip the rows.
# 52P.csv does not exists. Skip the rows.
# Figure saved: ../fig/53P.png
# Figure saved: ../fig/54P.png
# 55P.csv does not exists. Skip the rows.
# Figure saved: ../fig/56P.png
# Figure saved: ../fig/57P.png
# 58P.csv does not exists. Skip the rows.
# Figure saved: ../fig/59P.png
# Figure saved: ../fig/60P.png
# 61P.csv does not exists. Skip the rows.
# 62P.csv does not exists. Skip the rows.
# Figure saved: ../fig/63P.png
# Figure saved: ../fig/64P.png
# Figure saved: ../fig/65P.png
# 66P.csv does not exists. Skip the rows.
# Figure saved: ../fig/67P.png
# 68P.csv does not exists. Skip the rows.
# Figure saved: ../fig/69P.png
# Figure saved: ../fig/70P.png
# Figure saved: ../fig/71P.png
# 72P.csv does not exists. Skip the rows.
# Figure saved: ../fig/73P.png
# Figure saved: ../fig/74P.png
# 75D.csv does not exists. Skip the rows.
# Figure saved: ../fig/76P.png
# Figure saved: ../fig/77P.png
# Figure saved: ../fig/78P.png
# 79P.csv does not exists. Skip the rows.
# 80P.csv does not exists. Skip the rows.
# Figure saved: ../fig/81P.png
# Figure saved: ../fig/82P.png
# 83D.csv does not exists. Skip the rows.
# Figure saved: ../fig/84P.png
# 85D.csv does not exists. Skip the rows.
# Figure saved: ../fig/86P.png
# 87P.csv does not exists. Skip the rows.
# Figure saved: ../fig/88P.png
# Figure saved: ../fig/89P.png
# 90P.csv does not exists. Skip the rows.
# Figure saved: ../fig/91P.png
# Figure saved: ../fig/92P.png
# Figure saved: ../fig/93P.png
# Figure saved: ../fig/94P.png
# Figure saved: ../fig/96P.png
# 97P.csv does not exists. Skip the rows.
# Figure saved: ../fig/98P.png
# Figure saved: ../fig/99P.png
# 100P.csv does not exists. Skip the rows.
# 101P.csv does not exists. Skip the rows.
# Figure saved: ../fig/102P.png
# Figure saved: ../fig/103P.png
# Figure saved: ../fig/104P.png
# Figure saved: ../fig/105P.png
# 106P.csv does not exists. Skip the rows.
# 108P.csv does not exists. Skip the rows.
# 109P.csv does not exists. Skip the rows.
# Figure saved: ../fig/110P.png
# Figure saved: ../fig/111P.png
# Figure saved: ../fig/112P.png
# Figure saved: ../fig/113P.png
# Figure saved: ../fig/114P.png
# Figure saved: ../fig/115P.png
# Figure saved: ../fig/116P.png
# Figure saved: ../fig/117P.png
# Figure saved: ../fig/118P.png
# Figure saved: ../fig/119P.png
# 120P.csv does not exists. Skip the rows.
# Figure saved: ../fig/121P.png
# 122P.csv does not exists. Skip the rows.
# Figure saved: ../fig/123P.png
# Figure saved: ../fig/124P.png
# Figure saved: ../fig/125P.png
# Figure saved: ../fig/126P.png
# 127P.csv does not exists. Skip the rows.
# Figure saved: ../fig/128P.png
# Figure saved: ../fig/129P.png
# Figure saved: ../fig/130P.png
# Figure saved: ../fig/131P.png
# 132P.csv does not exists. Skip the rows.
# 134P.csv does not exists. Skip the rows.
# Figure saved: ../fig/135P.png
# Figure saved: ../fig/136P.png
# Figure saved: ../fig/137P.png
# Figure saved: ../fig/138P.png
# Figure saved: ../fig/139P.png
# 140P.csv does not exists. Skip the rows.
# Figure saved: ../fig/141P.png
# 142P.csv does not exists. Skip the rows.
# Figure saved: ../fig/143P.png
# 144P.csv does not exists. Skip the rows.
# Figure saved: ../fig/145P.png
# Figure saved: ../fig/146P.png
# Figure saved: ../fig/147P.png
# 148P.csv does not exists. Skip the rows.
# Figure saved: ../fig/149P.png
# Figure saved: ../fig/150P.png
# 151P.csv does not exists. Skip the rows.
# Figure saved: ../fig/152P.png
# 153P.csv does not exists. Skip the rows.
# Figure saved: ../fig/154P.png
# 155P.csv does not exists. Skip the rows.
# Figure saved: ../fig/156P.png
# Figure saved: ../fig/157P.png
# Figure saved: ../fig/158P.png
# Figure saved: ../fig/159P.png
# Figure saved: ../fig/160P.png
# Figure saved: ../fig/161P.png
# Figure saved: ../fig/162P.png
# Figure saved: ../fig/163P.png
# Figure saved: ../fig/164P.png
# 165P.csv does not exists. Skip the rows.
# 166P.csv does not exists. Skip the rows.
# 167P.csv does not exists. Skip the rows.
# Figure saved: ../fig/168P.png
# Figure saved: ../fig/169P.png
# Figure saved: ../fig/170P.png
# Figure saved: ../fig/171P.png
# Figure saved: ../fig/172P.png
# Figure saved: ../fig/173P.png
# Figure saved: ../fig/175P.png
# 177P.csv does not exists. Skip the rows.
# Figure saved: ../fig/178P.png
# Figure saved: ../fig/179P.png
# 180P.csv does not exists. Skip the rows.
# 181P.csv does not exists. Skip the rows.
# Figure saved: ../fig/182P.png
# Figure saved: ../fig/183P.png
# Figure saved: ../fig/184P.png
# Figure saved: ../fig/185P.png
# Figure saved: ../fig/186P.png
# Figure saved: ../fig/187P.png
# Figure saved: ../fig/188P.png
# Figure saved: ../fig/189P.png
# Figure saved: ../fig/190P.png
# Figure saved: ../fig/191P.png
# Figure saved: ../fig/192P.png
# Figure saved: ../fig/193P.png
# 194P.csv does not exists. Skip the rows.
# Figure saved: ../fig/195P.png
# 196P.csv does not exists. Skip the rows.
# Figure saved: ../fig/197P.png
# Figure saved: ../fig/198P.png
# Figure saved: ../fig/199P.png
# 200P.csv does not exists. Skip the rows.
# Figure saved: ../fig/201P.png
# Figure saved: ../fig/202P.png
# Figure saved: ../fig/203P.png
# 204P.csv does not exists. Skip the rows.
# Figure saved: ../fig/205P.png
# Figure saved: ../fig/206P.png
# 207P.csv does not exists. Skip the rows.
# Figure saved: ../fig/208P.png
# Figure saved: ../fig/209P.png
# Figure saved: ../fig/210P.png
# 211P.csv does not exists. Skip the rows.
# 212P.csv does not exists. Skip the rows.
# 213P.csv does not exists. Skip the rows.
# 214P.csv does not exists. Skip the rows.
# Figure saved: ../fig/215P.png
# 216P.csv does not exists. Skip the rows.
# Figure saved: ../fig/217P.png
# Figure saved: ../fig/218P.png
# Figure saved: ../fig/219P.png
# Figure saved: ../fig/220P.png
# Figure saved: ../fig/221P.png
# 222P.csv does not exists. Skip the rows.
# Figure saved: ../fig/223P.png
# 224P.csv does not exists. Skip the rows.
# 225P.csv does not exists. Skip the rows.
# 226P.csv does not exists. Skip the rows.
# 227P.csv does not exists. Skip the rows.
# Figure saved: ../fig/228P.png
# Figure saved: ../fig/229P.png
# Figure saved: ../fig/230P.png
# Figure saved: ../fig/231P.png
# Figure saved: ../fig/232P.png
# Figure saved: ../fig/233P.png
# Figure saved: ../fig/234P.png
# Figure saved: ../fig/235P.png
# Figure saved: ../fig/236P.png
# 237P.csv does not exists. Skip the rows.
# Figure saved: ../fig/238P.png
# Figure saved: ../fig/239P.png
# Figure saved: ../fig/240P.png
# 241P.csv does not exists. Skip the rows.
# Figure saved: ../fig/242P.png
# Figure saved: ../fig/243P.png
# Figure saved: ../fig/244P.png
# Figure saved: ../fig/245P.png
# Figure saved: ../fig/246P.png
# Figure saved: ../fig/247P.png
# Figure saved: ../fig/248P.png
# Figure saved: ../fig/249P.png
# Figure saved: ../fig/250P.png
# 251P.csv does not exists. Skip the rows.
# Figure saved: ../fig/252P.png
# Figure saved: ../fig/253P.png
# Figure saved: ../fig/254P.png
# Figure saved: ../fig/255P.png
# 256P.csv does not exists. Skip the rows.
# Figure saved: ../fig/257P.png
# Figure saved: ../fig/258P.png
# Figure saved: ../fig/259P.png
# Figure saved: ../fig/260P.png
# Figure saved: ../fig/261P.png
# 262P.csv does not exists. Skip the rows.
# Figure saved: ../fig/263P.png
# Figure saved: ../fig/264P.png
# 265P.csv does not exists. Skip the rows.
# Figure saved: ../fig/266P.png
# 267P.csv does not exists. Skip the rows.
# Figure saved: ../fig/268P.png
# Figure saved: ../fig/269P.png
# Figure saved: ../fig/270P.png
# 271P.csv does not exists. Skip the rows.
# 272P.csv does not exists. Skip the rows.
# 273P.csv does not exists. Skip the rows.
# 274P.csv does not exists. Skip the rows.
# Figure saved: ../fig/275P.png
# Figure saved: ../fig/276P.png
# Figure saved: ../fig/277P.png
# Figure saved: ../fig/278P.png
# 279P.csv does not exists. Skip the rows.
# Figure saved: ../fig/280P.png
# Figure saved: ../fig/281P.png
# Figure saved: ../fig/283P.png
# Figure saved: ../fig/284P.png
# Figure saved: ../fig/285P.png
# Figure saved: ../fig/286P.png
# Figure saved: ../fig/287P.png
# 289P.csv does not exists. Skip the rows.
# Figure saved: ../fig/290P.png
# 291P.csv does not exists. Skip the rows.
# Figure saved: ../fig/292P.png
# Figure saved: ../fig/293P.png
# Figure saved: ../fig/294P.png
# Figure saved: ../fig/295P.png
# Figure saved: ../fig/296P.png
# Figure saved: ../fig/297P.png
# Figure saved: ../fig/298P.png
# Figure saved: ../fig/299P.png
# Figure saved: ../fig/300P.png
# Figure saved: ../fig/301P.png
# Figure saved: ../fig/302P.png
# Figure saved: ../fig/303P.png
# Figure saved: ../fig/304P.png
# Figure saved: ../fig/305P.png
# Figure saved: ../fig/306P.png
# 307P.csv does not exists. Skip the rows.
# 308P.csv does not exists. Skip the rows.
# Figure saved: ../fig/309P.png
# Figure saved: ../fig/310P.png
# Figure saved: ../fig/311P.png
# Figure saved: ../fig/312P.png
# Figure saved: ../fig/313P.png
# 314P.csv does not exists. Skip the rows.
# Figure saved: ../fig/315P.png
# Figure saved: ../fig/316P.png
# Figure saved: ../fig/317P.png
# 318P.csv does not exists. Skip the rows.
# 319P.csv does not exists. Skip the rows.
# Figure saved: ../fig/320P.png
# Figure saved: ../fig/321P.png
# Figure saved: ../fig/322P.png
# Figure saved: ../fig/323P.png
# Figure saved: ../fig/324P.png
# 325P.csv does not exists. Skip the rows.
# Figure saved: ../fig/326P.png
# 327P.csv does not exists. Skip the rows.
# Figure saved: ../fig/328P.png
# Figure saved: ../fig/329P.png
# 330P.csv does not exists. Skip the rows.
# Figure saved: ../fig/331P.png
# Figure saved: ../fig/332P.png
# Figure saved: ../fig/333P.png
# 334P.csv does not exists. Skip the rows.
# 335P.csv does not exists. Skip the rows.
# Figure saved: ../fig/336P.png
# 337P.csv does not exists. Skip the rows.
# Figure saved: ../fig/338P.png
# 339P.csv does not exists. Skip the rows.
# Figure saved: ../fig/340P.png
# Figure saved: ../fig/341P.png
# Figure saved: ../fig/342P.png
# 343P.csv does not exists. Skip the rows.
# Figure saved: ../fig/344P.png
# Figure saved: ../fig/345P.png
# Figure saved: ../fig/346P.png
# Figure saved: ../fig/347P.png
# Figure saved: ../fig/348P.png
# Figure saved: ../fig/349P.png
# Figure saved: ../fig/350P.png
# Figure saved: ../fig/351P.png
# 352P.csv does not exists. Skip the rows.
# Figure saved: ../fig/353P.png
# Figure saved: ../fig/354P.png
# Figure saved: ../fig/355P.png
# Figure saved: ../fig/356P.png
# Figure saved: ../fig/357P.png
# 358P.csv does not exists. Skip the rows.
# Figure saved: ../fig/359P.png
# Figure saved: ../fig/360P.png
# Figure saved: ../fig/361P.png
# Figure saved: ../fig/363P.png
# Figure saved: ../fig/364P.png
# 365P.csv does not exists. Skip the rows.
# Figure saved: ../fig/366P.png
# Figure saved: ../fig/367P.png
# 368P.csv does not exists. Skip the rows.
# Figure saved: ../fig/369P.png
# 370P.csv does not exists. Skip the rows.
# Figure saved: ../fig/371P.png
# Figure saved: ../fig/372P.png
# Figure saved: ../fig/373P.png
# 374P.csv does not exists. Skip the rows.
# 375P.csv does not exists. Skip the rows.
# 376P.csv does not exists. Skip the rows.
# Figure saved: ../fig/377P.png
# Figure saved: ../fig/378P.png
# Figure saved: ../fig/379P.png
# Figure saved: ../fig/380P.png
# 381P.csv does not exists. Skip the rows.
# Figure saved: ../fig/382P.png
# Figure saved: ../fig/383P.png
# Figure saved: ../fig/384P.png
# Figure saved: ../fig/385P.png
# Figure saved: ../fig/386P.png
# 387P.csv does not exists. Skip the rows.
# 388P.csv does not exists. Skip the rows.
# 389P.csv does not exists. Skip the rows.
# 390P.csv does not exists. Skip the rows.
# Figure saved: ../fig/391P.png
# 392P.csv does not exists. Skip the rows.
# Figure saved: ../fig/393P.png
# Figure saved: ../fig/394P.png
# Figure saved: ../fig/395P.png
# 396P.csv does not exists. Skip the rows.
# Figure saved: ../fig/397P.png
# Figure saved: ../fig/398P.png
# Figure saved: ../fig/399P.png
# Figure saved: ../fig/400P.png
# 401P.csv does not exists. Skip the rows.
# Figure saved: ../fig/402P.png
# 403P.csv does not exists. Skip the rows.
# Figure saved: ../fig/404P.png
# Figure saved: ../fig/405P.png
# Figure saved: ../fig/406P.png
# Figure saved: ../fig/407P.png
# Figure saved: ../fig/408P.png
# 409P.csv does not exists. Skip the rows.
# 410P.csv does not exists. Skip the rows.
# 411P.csv does not exists. Skip the rows.
# Figure saved: ../fig/412P.png
# Figure saved: ../fig/413P.png
# Figure saved: ../fig/414P.png
# Figure saved: ../fig/415P.png
# 416P.csv does not exists. Skip the rows.
# Figure saved: ../fig/417P.png
# 418P.csv does not exists. Skip the rows.
# Figure saved: ../fig/419P.png
# Figure saved: ../fig/420P.png
# 421P.csv does not exists. Skip the rows.
# 422P.csv does not exists. Skip the rows.
# Figure saved: ../fig/423P.png
# 424P.csv does not exists. Skip the rows.
# 425P.csv does not exists. Skip the rows.
# Figure saved: ../fig/426P.png
# Figure saved: ../fig/427P.png
# Figure saved: ../fig/428P.png
# 429P.csv does not exists. Skip the rows.
# Figure saved: ../fig/430P.png
# Figure saved: ../fig/431P.png
# Figure saved: ../fig/432P.png
# 434P.csv does not exists. Skip the rows.
# Figure saved: ../fig/435P.png
# 436P.csv does not exists. Skip the rows.
# 437P.csv does not exists. Skip the rows.
# Figure saved: ../fig/438P.png
# Figure saved: ../fig/439P.png
# 440P.csv does not exists. Skip the rows.
# Figure saved: ../fig/441P.png
# 442P.csv does not exists. Skip the rows.
# 443P.csv does not exists. Skip the rows.
# 444P.csv does not exists. Skip the rows.
# 445P.csv does not exists. Skip the rows.
# 446P.csv does not exists. Skip the rows.
# Figure saved: ../fig/447P.png
# 448P.csv does not exists. Skip the rows.
# Figure saved: ../fig/449P.png
# Figure saved: ../fig/450P.png
# 451P.csv does not exists. Skip the rows.
# Figure saved: ../fig/452P.png
# 453P.csv does not exists. Skip the rows.
# 454P.csv does not exists. Skip the rows.
# 455P.csv does not exists. Skip the rows.
# Figure saved: ../fig/456P.png
# 457P.csv does not exists. Skip the rows.
# 458P.csv does not exists. Skip the rows.
# Figure saved: ../fig/459P.png
# Figure saved: ../fig/460P.png
# Figure saved: ../fig/461P.png
# 462P.csv does not exists. Skip the rows.
# 463P.csv does not exists. Skip the rows.
# Figure saved: ../fig/464P.png
# 465P.csv does not exists. Skip the rows.
# 466P.csv does not exists. Skip the rows.
# Figure saved: ../fig/467P.png
# Figure saved: ../fig/468P.png
# Figure saved: ../fig/469P.png
# Figure saved: ../fig/470P.png
# Figure saved: ../fig/471P.png
# Figure saved: ../fig/472P.png
# 473P.csv does not exists. Skip the rows.
# 474P.csv does not exists. Skip the rows.
# Figure saved: ../fig/475P.png
# Figure saved: ../fig/476P.png
# 477P.csv does not exists. Skip the rows.
# Figure saved: ../fig/478P.png
# Figure saved: ../fig/479P.png
# Figure saved: ../fig/480P.png
# Figure saved: ../fig/481P.png
# Figure saved: ../fig/482P.png
# Figure saved: ../fig/484P.png
# Figure saved: ../fig/485P.png
# Figure saved: ../fig/486P.png
# Figure saved: ../fig/487P.png
# 488P.csv does not exists. Skip the rows.
# Figure saved: ../fig/489P.png
# Figure saved: ../fig/490P.png
# Figure saved: ../fig/491P.png
# Figure saved: ../fig/492P.png
# Figure saved: ../fig/493P.png
# Figure saved: ../fig/494P.png
# Figure saved: ../fig/495P.png
# Figure saved: ../fig/496P.png
# Figure saved: ../fig/497P.png
# Figure saved: ../fig/498P.png
# Figure saved: ../fig/499P.png
# Figure saved: ../fig/500P.png
# Figure saved: ../fig/501P.png
# Figure saved: ../fig/502P.png
# Figure saved: ../fig/503P.png
# Figure saved: ../fig/504P.png
# Figure saved: ../fig/505P.png
# 506P.csv does not exists. Skip the rows.
# Figure saved: ../fig/507P.png
# Figure saved: ../fig/508P.png
# Figure saved: ../fig/509P.png
# Figure saved: ../fig/510P.png
# -146P1.csv does not exists. Skip the rows.
# -43K1.csv does not exists. Skip the rows.
# 240V1.csv does not exists. Skip the rows.
# 390Q1.csv does not exists. Skip the rows.
# 400F1.csv does not exists. Skip the rows.
# 418M1.csv does not exists. Skip the rows.
# 442V1.csv does not exists. Skip the rows.
# 539W1.csv does not exists. Skip the rows.
# 565O1.csv does not exists. Skip the rows.
# 568O1.csv does not exists. Skip the rows.
# 574G1.csv does not exists. Skip the rows.
# 770K1.csv does not exists. Skip the rows.
# 817C1.csv does not exists. Skip the rows.
# 868B1.csv does not exists. Skip the rows.
# 905K1.csv does not exists. Skip the rows.
# 962B1.csv does not exists. Skip the rows.
# 1014C1.csv does not exists. Skip the rows.
# 1018P1.csv does not exists. Skip the rows.
# 1080P1.csv does not exists. Skip the rows.
# 1092A1.csv does not exists. Skip the rows.
# 1097T1.csv does not exists. Skip the rows.
# 1110K1.csv does not exists. Skip the rows.
# 1132T1.csv does not exists. Skip the rows.
# 1147A1.csv does not exists. Skip the rows.
# 1230X1.csv does not exists. Skip the rows.
# 1240B1.csv does not exists. Skip the rows.
# 1245D1.csv does not exists. Skip the rows.
# 1264N1.csv does not exists. Skip the rows.
# 1293V1.csv does not exists. Skip the rows.
# 1299B1.csv does not exists. Skip the rows.
# 1304C1.csv does not exists. Skip the rows.
# 1304Y1.csv does not exists. Skip the rows.
# 1315U1.csv does not exists. Skip the rows.
# 1337M1.csv does not exists. Skip the rows.
# 1340F1.csv does not exists. Skip the rows.
# 1345O1.csv does not exists. Skip the rows.
# 1351W1.csv does not exists. Skip the rows.
# 1362E1.csv does not exists. Skip the rows.
# 1368E1.csv does not exists. Skip the rows.
# 1376M1.csv does not exists. Skip the rows.
# 1402D1.csv does not exists. Skip the rows.
# 1433R1.csv does not exists. Skip the rows.
# 1439F1.csv does not exists. Skip the rows.
# 1449Y1.csv does not exists. Skip the rows.
# 1457L1.csv does not exists. Skip the rows.
# 1458Y1.csv does not exists. Skip the rows.
# 1462M1.csv does not exists. Skip the rows.
# 1468S1.csv does not exists. Skip the rows.
# 1471Y1.csv does not exists. Skip the rows.
# 1490Y1.csv does not exists. Skip the rows.
# 1499Q1.csv does not exists. Skip the rows.
# 1500H1.csv does not exists. Skip the rows.
# 1506O1.csv does not exists. Skip the rows.
# 1532R1.csv does not exists. Skip the rows.
# 1533M1.csv does not exists. Skip the rows.
# 1538A1.csv does not exists. Skip the rows.
# 1539H1.csv does not exists. Skip the rows.
# 1556D1.csv does not exists. Skip the rows.
# 1557T1.csv does not exists. Skip the rows.
# 1558P1.csv does not exists. Skip the rows.
# 1577V1.csv does not exists. Skip the rows.
# 1580T1.csv does not exists. Skip the rows.
# 1582J1.csv does not exists. Skip the rows.
# 1585T1.csv does not exists. Skip the rows.
# 1590E1.csv does not exists. Skip the rows.
# 1593O1.csv does not exists. Skip the rows.
# 1596N1.csv does not exists. Skip the rows.
# 1618Q1.csv does not exists. Skip the rows.
# 1618V1.csv does not exists. Skip the rows.
# 1618W1.csv does not exists. Skip the rows.
# 1639U1.csv does not exists. Skip the rows.
# 1652Y1.csv does not exists. Skip the rows.
# 1661C1.csv does not exists. Skip the rows.
# 1664W1.csv does not exists. Skip the rows.
# 1665F1.csv does not exists. Skip the rows.
# 1668E1.csv does not exists. Skip the rows.
# 1672E1.csv does not exists. Skip the rows.
# 1677H1.csv does not exists. Skip the rows.
# 1680V1.csv does not exists. Skip the rows.
# 1683O1.csv does not exists. Skip the rows.
# 1684N1.csv does not exists. Skip the rows.
# 1686R1.csv does not exists. Skip the rows.
# 1689X1.csv does not exists. Skip the rows.
# 1695U1.csv does not exists. Skip the rows.
# 1698R1.csv does not exists. Skip the rows.
# 1699D1.csv does not exists. Skip the rows.
# 1701U1.csv does not exists. Skip the rows.
# 1702H1.csv does not exists. Skip the rows.
# 1706F1.csv does not exists. Skip the rows.
# 1707W1.csv does not exists. Skip the rows.
# 1718B1.csv does not exists. Skip the rows.
# 1723T1.csv does not exists. Skip the rows.
# 1729P1.csv does not exists. Skip the rows.
# 1733K1.csv does not exists. Skip the rows.
# 1737C1.csv does not exists. Skip the rows.
# 1739K1.csv does not exists. Skip the rows.
# 1742C1.csv does not exists. Skip the rows.
# 1743C1.csv does not exists. Skip the rows.
# 1743Q1.csv does not exists. Skip the rows.
# 1743X1.csv does not exists. Skip the rows.
# 1746P1.csv does not exists. Skip the rows.
# 1748H1.csv does not exists. Skip the rows.
# 1748K1.csv does not exists. Skip the rows.
# 1750C1.csv does not exists. Skip the rows.
# 1757R1.csv does not exists. Skip the rows.
# 1758K1.csv does not exists. Skip the rows.
# 1760A1.csv does not exists. Skip the rows.
# 1760B1.csv does not exists. Skip the rows.
# 1762K1.csv does not exists. Skip the rows.
# 1763S1.csv does not exists. Skip the rows.
# 1764A1.csv does not exists. Skip the rows.
# 1766E1.csv does not exists. Skip the rows.
# 1766G1.csv does not exists. Skip the rows.
# 1769P1.csv does not exists. Skip the rows.
# 1770L1.csv does not exists. Skip the rows.
# 1771A1.csv does not exists. Skip the rows.
# 1771G1.csv does not exists. Skip the rows.
# 1773T1.csv does not exists. Skip the rows.
# 1774P1.csv does not exists. Skip the rows.
# 1779A1.csv does not exists. Skip the rows.
# 1780U1.csv does not exists. Skip the rows.
# 1780U2.csv does not exists. Skip the rows.
# 1781M1.csv does not exists. Skip the rows.
# 1781T1.csv does not exists. Skip the rows.
# 1783X1.csv does not exists. Skip the rows.
# 1785A1.csv does not exists. Skip the rows.
# 1785E1.csv does not exists. Skip the rows.
# 1786P1.csv does not exists. Skip the rows.
# 1787G1.csv does not exists. Skip the rows.
# 1788W1.csv does not exists. Skip the rows.
# 1790A1.csv does not exists. Skip the rows.
# 1790H1.csv does not exists. Skip the rows.
# 1791X1.csv does not exists. Skip the rows.
# 1793A1.csv does not exists. Skip the rows.
# 1793S1.csv does not exists. Skip the rows.
# 1793S2.csv does not exists. Skip the rows.
# 1796F1.csv does not exists. Skip the rows.
# 1797P1.csv does not exists. Skip the rows.
# 1798G1.csv does not exists. Skip the rows.
# 1798X1.csv does not exists. Skip the rows.
# 1799P1.csv does not exists. Skip the rows.
# 1799Y1.csv does not exists. Skip the rows.
# 1801N1.csv does not exists. Skip the rows.
# 1802Q1.csv does not exists. Skip the rows.
# 1804E1.csv does not exists. Skip the rows.
# 1806V1.csv does not exists. Skip the rows.
# 1807R1.csv does not exists. Skip the rows.
# 1808F1.csv does not exists. Skip the rows.
# 1808M1.csv does not exists. Skip the rows.
# 1808R1.csv does not exists. Skip the rows.
# 1810Q1.csv does not exists. Skip the rows.
# 1811F1.csv does not exists. Skip the rows.
# 1811W1.csv does not exists. Skip the rows.
# 1813C1.csv does not exists. Skip the rows.
# 1813G1.csv does not exists. Skip the rows.
# 1816B1.csv does not exists. Skip the rows.
# 1817Y1.csv does not exists. Skip the rows.
# 1818W2.csv does not exists. Skip the rows.
# 1819N1.csv does not exists. Skip the rows.
# 1821B1.csv does not exists. Skip the rows.
# 1822J1.csv does not exists. Skip the rows.
# 1822K1.csv does not exists. Skip the rows.
# 1822N1.csv does not exists. Skip the rows.
# 1823Y1.csv does not exists. Skip the rows.
# 1824N1.csv does not exists. Skip the rows.
# 1824O1.csv does not exists. Skip the rows.
# 1825K1.csv does not exists. Skip the rows.
# 1825N1.csv does not exists. Skip the rows.
# 1825P1.csv does not exists. Skip the rows.
# 1825V1.csv does not exists. Skip the rows.
# 1826P1.csv does not exists. Skip the rows.
# 1826U1.csv does not exists. Skip the rows.
# 1826Y1.csv does not exists. Skip the rows.
# 1827P1.csv does not exists. Skip the rows.
# 1830F1.csv does not exists. Skip the rows.
# 1831A1.csv does not exists. Skip the rows.
# 1832O1.csv does not exists. Skip the rows.
# 1833S1.csv does not exists. Skip the rows.
# 1834E1.csv does not exists. Skip the rows.
# 1835H1.csv does not exists. Skip the rows.
# 1839X1.csv does not exists. Skip the rows.
# 1840B1.csv does not exists. Skip the rows.
# 1840E1.csv does not exists. Skip the rows.
# 1840U1.csv does not exists. Skip the rows.
# 1842U1.csv does not exists. Skip the rows.
# 1843D1.csv does not exists. Skip the rows.
# 1843J1.csv does not exists. Skip the rows.
# 1844N1.csv does not exists. Skip the rows.
# 1844Y1.csv does not exists. Skip the rows.
# 1844Y2.csv does not exists. Skip the rows.
# 1845D1.csv does not exists. Skip the rows.
# 1845L1.csv does not exists. Skip the rows.
# 1846B1.csv does not exists. Skip the rows.
# 1846J1.csv does not exists. Skip the rows.
# 1846O1.csv does not exists. Skip the rows.
# 1846S1.csv does not exists. Skip the rows.
# 1847C1.csv does not exists. Skip the rows.
# 1847J1.csv does not exists. Skip the rows.
# 1847N1.csv does not exists. Skip the rows.
# 1847Q1.csv does not exists. Skip the rows.
# 1847T1.csv does not exists. Skip the rows.
# 1848P1.csv does not exists. Skip the rows.
# 1848U1.csv does not exists. Skip the rows.
# 1849G1.csv does not exists. Skip the rows.
# 1849G2.csv does not exists. Skip the rows.
# 1850J1.csv does not exists. Skip the rows.
# 1850Q1.csv does not exists. Skip the rows.
# 1851P1.csv does not exists. Skip the rows.
# 1851U1.csv does not exists. Skip the rows.
# 1852K1.csv does not exists. Skip the rows.
# 1853E1.csv does not exists. Skip the rows.
# 1853G1.csv does not exists. Skip the rows.
# 1853L1.csv does not exists. Skip the rows.
# 1853R1.csv does not exists. Skip the rows.
# 1853W1.csv does not exists. Skip the rows.
# 1854F1.csv does not exists. Skip the rows.
# 1854L1.csv does not exists. Skip the rows.
# 1854R1.csv does not exists. Skip the rows.
# 1854Y1.csv does not exists. Skip the rows.
# 1855G1.csv does not exists. Skip the rows.
# 1855L1.csv does not exists. Skip the rows.
# 1855V1.csv does not exists. Skip the rows.
# 1857D1.csv does not exists. Skip the rows.
# 1857M1.csv does not exists. Skip the rows.
# 1857O1.csv does not exists. Skip the rows.
# 1857Q1.csv does not exists. Skip the rows.
# 1857V1.csv does not exists. Skip the rows.
# 1858K1.csv does not exists. Skip the rows.
# 1858L1.csv does not exists. Skip the rows.
# 1858R1.csv does not exists. Skip the rows.
# 1859G1.csv does not exists. Skip the rows.
# 1860H1.csv does not exists. Skip the rows.
# 1860M1.csv does not exists. Skip the rows.
# 1860U1.csv does not exists. Skip the rows.
# 1861G1.csv does not exists. Skip the rows.
# 1861J1.csv does not exists. Skip the rows.
# 1861Y1.csv does not exists. Skip the rows.
# 1862N1.csv does not exists. Skip the rows.
# 1862W1.csv does not exists. Skip the rows.
# 1862X1.csv does not exists. Skip the rows.
# 1863G1.csv does not exists. Skip the rows.
# 1863G2.csv does not exists. Skip the rows.
# 1863T1.csv does not exists. Skip the rows.
# 1863V1.csv does not exists. Skip the rows.
# 1863Y1.csv does not exists. Skip the rows.
# 1864N1.csv does not exists. Skip the rows.
# 1864O1.csv does not exists. Skip the rows.
# 1864R1.csv does not exists. Skip the rows.
# 1864X1.csv does not exists. Skip the rows.
# 1864Y1.csv does not exists. Skip the rows.
# 1865B1.csv does not exists. Skip the rows.
# 1867S1.csv does not exists. Skip the rows.
# 1868L1.csv does not exists. Skip the rows.
# 1869T1.csv does not exists. Skip the rows.
# 1870K1.csv does not exists. Skip the rows.
# 1870Q1.csv does not exists. Skip the rows.
# 1870W1.csv does not exists. Skip the rows.
# 1871G1.csv does not exists. Skip the rows.
# 1871L1.csv does not exists. Skip the rows.
# 1871V1.csv does not exists. Skip the rows.
# 1873Q1.csv does not exists. Skip the rows.
# 1873Q2.csv does not exists. Skip the rows.
# 1874D1.csv does not exists. Skip the rows.
# 1874G1.csv does not exists. Skip the rows.
# 1874H1.csv does not exists. Skip the rows.
# 1874O1.csv does not exists. Skip the rows.
# 1874Q1.csv does not exists. Skip the rows.
# 1874X1.csv does not exists. Skip the rows.
# 1877C1.csv does not exists. Skip the rows.
# 1877G1.csv does not exists. Skip the rows.
# 1877G2.csv does not exists. Skip the rows.
# 1877R1.csv does not exists. Skip the rows.
# 1877T1.csv does not exists. Skip the rows.
# 1878N1.csv does not exists. Skip the rows.
# 1879M1.csv does not exists. Skip the rows.
# 1879Q1.csv does not exists. Skip the rows.
# 1879Q2.csv does not exists. Skip the rows.
# 1880C1.csv does not exists. Skip the rows.
# 1880G1.csv does not exists. Skip the rows.
# 1880S1.csv does not exists. Skip the rows.
# 1880Y1.csv does not exists. Skip the rows.
# 1881J1.csv does not exists. Skip the rows.
# 1881K1.csv does not exists. Skip the rows.
# 1881N1.csv does not exists. Skip the rows.
# 1881S1.csv does not exists. Skip the rows.
# 1881W1.csv does not exists. Skip the rows.
# 1882F1.csv does not exists. Skip the rows.
# 1882R2.csv does not exists. Skip the rows.
# 1883D1.csv does not exists. Skip the rows.
# 1884A1.csv does not exists. Skip the rows.
# 1884O1.csv does not exists. Skip the rows.
# 1885N1.csv does not exists. Skip the rows.
# 1885R1.csv does not exists. Skip the rows.
# 1885X1.csv does not exists. Skip the rows.
# 1885X2.csv does not exists. Skip the rows.
# 1885Y1.csv does not exists. Skip the rows.
# 1886H1.csv does not exists. Skip the rows.
# 1886J1.csv does not exists. Skip the rows.
# 1886K1.csv does not exists. Skip the rows.
# 1886T1.csv does not exists. Skip the rows.
# 1887B1.csv does not exists. Skip the rows.
# 1887B2.csv does not exists. Skip the rows.
# 1887B3.csv does not exists. Skip the rows.
# 1887D1.csv does not exists. Skip the rows.
# 1887J1.csv does not exists. Skip the rows.
# 1888D1.csv does not exists. Skip the rows.
# 1888P1.csv does not exists. Skip the rows.
# 1888R1.csv does not exists. Skip the rows.
# 1888U1.csv does not exists. Skip the rows.
# 1889G1.csv does not exists. Skip the rows.
# 1889O1.csv does not exists. Skip the rows.
# 1889X1.csv does not exists. Skip the rows.
# 1890F1.csv does not exists. Skip the rows.
# 1890O1.csv does not exists. Skip the rows.
# 1890O2.csv does not exists. Skip the rows.
# 1890V1.csv does not exists. Skip the rows.
# 1891F1.csv does not exists. Skip the rows.
# 1891T1.csv does not exists. Skip the rows.
# 1892E1.csv does not exists. Skip the rows.
# 1892F1.csv does not exists. Skip the rows.
# 1892Q1.csv does not exists. Skip the rows.
# 1892W1.csv does not exists. Skip the rows.
# 1893N1.csv does not exists. Skip the rows.
# 1893U1.csv does not exists. Skip the rows.
# 1894G1.csv does not exists. Skip the rows.
# 1895Q1.csv does not exists. Skip the rows.
# 1895W1.csv does not exists. Skip the rows.
# 1895W2.csv does not exists. Skip the rows.
# 1896C1.csv does not exists. Skip the rows.
# 1896G1.csv does not exists. Skip the rows.
# 1896R1.csv does not exists. Skip the rows.
# 1896V1.csv does not exists. Skip the rows.
# 1897U1.csv does not exists. Skip the rows.
# 1898F1.csv does not exists. Skip the rows.
# 1898L1.csv does not exists. Skip the rows.
# 1898L2.csv does not exists. Skip the rows.
# 1898M1.csv does not exists. Skip the rows.
# 1898R1.csv does not exists. Skip the rows.
# 1898U1.csv does not exists. Skip the rows.
# 1898V1.csv does not exists. Skip the rows.
# 1899E1.csv does not exists. Skip the rows.
# 1899S1.csv does not exists. Skip the rows.
# 1900B1.csv does not exists. Skip the rows.
# 1900O1.csv does not exists. Skip the rows.
# 1901G1.csv does not exists. Skip the rows.
# 1902G1.csv does not exists. Skip the rows.
# 1902R1.csv does not exists. Skip the rows.
# 1902X1.csv does not exists. Skip the rows.
# 1903A1.csv does not exists. Skip the rows.
# 1903H1.csv does not exists. Skip the rows.
# 1903M1.csv does not exists. Skip the rows.
# 1904H1.csv does not exists. Skip the rows.
# 1904Y1.csv does not exists. Skip the rows.
# 1905F1.csv does not exists. Skip the rows.
# 1905W1.csv does not exists. Skip the rows.
# 1905X1.csv does not exists. Skip the rows.
# 1906B1.csv does not exists. Skip the rows.
# 1906E1.csv does not exists. Skip the rows.
# 1906F1.csv does not exists. Skip the rows.
# 1906V1.csv does not exists. Skip the rows.
# 1907E1.csv does not exists. Skip the rows.
# 1907G1.csv does not exists. Skip the rows.
# 1907L2.csv does not exists. Skip the rows.
# 1907T1.csv does not exists. Skip the rows.
# 1908R1.csv does not exists. Skip the rows.
# 1909L1.csv does not exists. Skip the rows.
# 1910A1.csv does not exists. Skip the rows.
# 1910P1.csv does not exists. Skip the rows.
# 1911N1.csv does not exists. Skip the rows.
# 1911O1.csv does not exists. Skip the rows.
# 1911S2.csv does not exists. Skip the rows.
# 1911S3.csv does not exists. Skip the rows.
# 1912R1.csv does not exists. Skip the rows.
# 1912V1.csv does not exists. Skip the rows.
# 1913J1.csv does not exists. Skip the rows.
# 1913R1.csv does not exists. Skip the rows.
# 1913Y1.csv does not exists. Skip the rows.
# 1914F1.csv does not exists. Skip the rows.
# 1914J1.csv does not exists. Skip the rows.
# 1914M1.csv does not exists. Skip the rows.
# 1914S1.csv does not exists. Skip the rows.
# 1915C1.csv does not exists. Skip the rows.
# 1915R1.csv does not exists. Skip the rows.
# 1916G1.csv does not exists. Skip the rows.
# 1917F1.csv does not exists. Skip the rows.
# 1917H1.csv does not exists. Skip the rows.
# 1918L1.csv does not exists. Skip the rows.
# 1918W1.csv does not exists. Skip the rows.
# 1919Q2.csv does not exists. Skip the rows.
# 1919Y1.csv does not exists. Skip the rows.
# 1920X1.csv does not exists. Skip the rows.
# 1921E1.csv does not exists. Skip the rows.
# 1921H1.csv does not exists. Skip the rows.
# 1922B1.csv does not exists. Skip the rows.
# 1922U1.csv does not exists. Skip the rows.
# 1922W1.csv does not exists. Skip the rows.
# 1923T1.csv does not exists. Skip the rows.
# 1924F1.csv does not exists. Skip the rows.
# 1924R1.csv does not exists. Skip the rows.
# 1925F1.csv does not exists. Skip the rows.
# 1925F2.csv does not exists. Skip the rows.
# 1925G1.csv does not exists. Skip the rows.
# 1925V1.csv does not exists. Skip the rows.
# 1925W1.csv does not exists. Skip the rows.
# 1925X1.csv does not exists. Skip the rows.
# 1926B1.csv does not exists. Skip the rows.
# 1927A1.csv does not exists. Skip the rows.
# 1927B1.csv does not exists. Skip the rows.
# 1927E1.csv does not exists. Skip the rows.
# 1927X1.csv does not exists. Skip the rows.
# 1929Y1.csv does not exists. Skip the rows.
# 1930D1.csv does not exists. Skip the rows.
# 1930E1.csv does not exists. Skip the rows.
# 1930F1.csv does not exists. Skip the rows.
# 1930L1.csv does not exists. Skip the rows.
# 1931O1.csv does not exists. Skip the rows.
# 1931P1.csv does not exists. Skip the rows.
# 1932G1.csv does not exists. Skip the rows.
# 1932H1.csv does not exists. Skip the rows.
# 1932M1.csv does not exists. Skip the rows.
# 1932M2.csv does not exists. Skip the rows.
# 1932P1.csv does not exists. Skip the rows.
# 1932Y1.csv does not exists. Skip the rows.
# 1933D1.csv does not exists. Skip the rows.
# 1935A1.csv does not exists. Skip the rows.
# 1935M1.csv does not exists. Skip the rows.
# 1935Q1.csv does not exists. Skip the rows.
# 1936K1.csv does not exists. Skip the rows.
# 1936O1.csv does not exists. Skip the rows.
# 1937C1.csv does not exists. Skip the rows.
# 1937D1.csv does not exists. Skip the rows.
# 1937N1.csv does not exists. Skip the rows.
# 1937P1.csv does not exists. Skip the rows.
# 1939B1.csv does not exists. Skip the rows.
# 1939H1.csv does not exists. Skip the rows.
# 1939V1.csv does not exists. Skip the rows.
# 1940O1.csv does not exists. Skip the rows.
# 1940R2.csv does not exists. Skip the rows.
# 1940S1.csv does not exists. Skip the rows.
# 1941B1.csv does not exists. Skip the rows.
# 1941B2.csv does not exists. Skip the rows.
# 1941K1.csv does not exists. Skip the rows.
# 1942C1.csv does not exists. Skip the rows.
# 1942C2.csv does not exists. Skip the rows.
# 1942EA.csv does not exists. Skip the rows.
# 1942X1.csv does not exists. Skip the rows.
# 1943R1.csv does not exists. Skip the rows.
# 1943W1.csv does not exists. Skip the rows.
# 1944H1.csv does not exists. Skip the rows.
# 1944K2.csv does not exists. Skip the rows.
# 1945L1.csv does not exists. Skip the rows.
# 1945W1.csv does not exists. Skip the rows.
# 1945X1.csv does not exists. Skip the rows.
# 1946C1.csv does not exists. Skip the rows.
# 1946K1.csv does not exists. Skip the rows.
# 1946P1.csv does not exists. Skip the rows.
# 1946U1.csv does not exists. Skip the rows.
# 1947F1.csv does not exists. Skip the rows.
# 1947F2.csv does not exists. Skip the rows.
# 1947K1.csv does not exists. Skip the rows.
# 1947O1.csv does not exists. Skip the rows.
# 1947S1.csv does not exists. Skip the rows.
# 1947V1.csv does not exists. Skip the rows.
# 1947Y1.csv does not exists. Skip the rows.
# 1948E1.csv does not exists. Skip the rows.
# 1948L1.csv does not exists. Skip the rows.
# 1948N1.csv does not exists. Skip the rows.
# 1948R1.csv does not exists. Skip the rows.
# 1948T1.csv does not exists. Skip the rows.
# 1948V1.csv does not exists. Skip the rows.
# 1948W1.csv does not exists. Skip the rows.
# 1949K1.csv does not exists. Skip the rows.
# 1949N1.csv does not exists. Skip the rows.
# 1950K1.csv does not exists. Skip the rows.
# 1951C1.csv does not exists. Skip the rows.
# 1951G1.csv does not exists. Skip the rows.
# 1951G2.csv does not exists. Skip the rows.
# 1951P1.csv does not exists. Skip the rows.
# 1952B1.csv does not exists. Skip the rows.
# 1952H1.csv does not exists. Skip the rows.
# 1952M1.csv does not exists. Skip the rows.
# 1952Q1.csv does not exists. Skip the rows.
# 1952W1.csv does not exists. Skip the rows.
# 1953G1.csv does not exists. Skip the rows.
# 1953T1.csv does not exists. Skip the rows.
# 1953X1.csv does not exists. Skip the rows.
# 1954M1.csv does not exists. Skip the rows.
# 1954M2.csv does not exists. Skip the rows.
# 1954O1.csv does not exists. Skip the rows.
# 1954O2.csv does not exists. Skip the rows.
# 1954Y1.csv does not exists. Skip the rows.
# 1955G1.csv does not exists. Skip the rows.
# 1955L1.csv does not exists. Skip the rows.
# 1955N1.csv does not exists. Skip the rows.
# 1955O1.csv does not exists. Skip the rows.
# 1956E1.csv does not exists. Skip the rows.
# 1956R1.csv does not exists. Skip the rows.
# 1957P1.csv does not exists. Skip the rows.
# 1957U1.csv does not exists. Skip the rows.
# 1958D1.csv does not exists. Skip the rows.
# 1958R1.csv does not exists. Skip the rows.
# 1959O1.csv does not exists. Skip the rows.
# 1959Q1.csv does not exists. Skip the rows.
# 1959Q2.csv does not exists. Skip the rows.
# 1959X1.csv does not exists. Skip the rows.
# 1959Y1.csv does not exists. Skip the rows.
# 1960B1.csv does not exists. Skip the rows.
# 1960M1.csv does not exists. Skip the rows.
# 1960Y1.csv does not exists. Skip the rows.
# 1961O1.csv does not exists. Skip the rows.
# 1961R1.csv does not exists. Skip the rows.
# 1961T1.csv does not exists. Skip the rows.
# 1962C1.csv does not exists. Skip the rows.
# 1962H1.csv does not exists. Skip the rows.
# 1963A1.csv does not exists. Skip the rows.
# 1963F1.csv does not exists. Skip the rows.
# 1963R1.csv does not exists. Skip the rows.
# 1964L1.csv does not exists. Skip the rows.
# 1964N1.csv does not exists. Skip the rows.
# 1964P1.csv does not exists. Skip the rows.
# 1965S2.csv does not exists. Skip the rows.
# 1966P1.csv does not exists. Skip the rows.
# 1966P2.csv does not exists. Skip the rows.
# 1966R1.csv does not exists. Skip the rows.
# 1966T1.csv does not exists. Skip the rows.
# 1967C1.csv does not exists. Skip the rows.
# 1967C2.csv does not exists. Skip the rows.
# 1967M1.csv does not exists. Skip the rows.
# 1967Y1.csv does not exists. Skip the rows.
# 1968H1.csv does not exists. Skip the rows.
# 1968L1.csv does not exists. Skip the rows.
# 1968N1.csv does not exists. Skip the rows.
# 1968Q1.csv does not exists. Skip the rows.
# 1968Q2.csv does not exists. Skip the rows.
# 1968U1.csv does not exists. Skip the rows.
# 1968Y1.csv does not exists. Skip the rows.
# 1969P1.csv does not exists. Skip the rows.
# 1969T1.csv does not exists. Skip the rows.
# 1969Y1.csv does not exists. Skip the rows.
# 1970B1.csv does not exists. Skip the rows.
# 1970K1.csv does not exists. Skip the rows.
# 1970N1.csv does not exists. Skip the rows.
# 1970U1.csv does not exists. Skip the rows.
# 1971E1.csv does not exists. Skip the rows.
# 1971M1.csv does not exists. Skip the rows.
# 1972E1.csv does not exists. Skip the rows.
# 1972F1.csv does not exists. Skip the rows.
# 1972L1.csv does not exists. Skip the rows.
# 1972U1.csv does not exists. Skip the rows.
# 1972X1.csv does not exists. Skip the rows.
# 1973A1.csv does not exists. Skip the rows.
# 1973D1.csv does not exists. Skip the rows.
# 1973E1.csv does not exists. Skip the rows.
# 1973H1.csv does not exists. Skip the rows.
# 1973N1.csv does not exists. Skip the rows.
# 1973W1.csv does not exists. Skip the rows.
# 1974C1.csv does not exists. Skip the rows.
# 1974F1.csv does not exists. Skip the rows.
# 1974O1.csv does not exists. Skip the rows.
# 1974V1.csv does not exists. Skip the rows.
# 1974V2.csv does not exists. Skip the rows.
# 1975E1.csv does not exists. Skip the rows.
# 1975N1.csv does not exists. Skip the rows.
# 1975T1.csv does not exists. Skip the rows.
# 1975T2.csv does not exists. Skip the rows.
# 1975V2.csv does not exists. Skip the rows.
# 1975X1.csv does not exists. Skip the rows.
# 1976D1.csv does not exists. Skip the rows.
# 1976D2.csv does not exists. Skip the rows.
# 1976E1.csv does not exists. Skip the rows.
# 1976J1.csv does not exists. Skip the rows.
# 1976U1.csv does not exists. Skip the rows.
# 1977C1.csv does not exists. Skip the rows.
# 1977D1.csv does not exists. Skip the rows.
# 1977H1.csv does not exists. Skip the rows.
# 1977R1.csv does not exists. Skip the rows.
# 1977V1.csv does not exists. Skip the rows.
# 1978A1.csv does not exists. Skip the rows.
# 1978C1.csv does not exists. Skip the rows.
# 1978G2.csv does not exists. Skip the rows.
# 1978H1.csv does not exists. Skip the rows.
# 1978R1.csv does not exists. Skip the rows.
# 1978R3.csv does not exists. Skip the rows.
# 1978T1.csv does not exists. Skip the rows.
# 1978T3.csv does not exists. Skip the rows.
# 1979M1.csv does not exists. Skip the rows.
# 1979M3.csv does not exists. Skip the rows.
# 1979Q1.csv does not exists. Skip the rows.
# 1979S1.csv does not exists. Skip the rows.
# 1979Y1.csv does not exists. Skip the rows.
# 1980E1.csv does not exists. Skip the rows.
# 1980L1.csv does not exists. Skip the rows.
# 1980O1.csv does not exists. Skip the rows.
# 1980R1.csv does not exists. Skip the rows.
# 1980V1.csv does not exists. Skip the rows.
# 1980Y1.csv does not exists. Skip the rows.
# 1980Y2.csv does not exists. Skip the rows.
# 1981B1.csv does not exists. Skip the rows.
# 1981G1.csv does not exists. Skip the rows.
# 1981H1.csv does not exists. Skip the rows.
# 1981M1.csv does not exists. Skip the rows.
# 1981O1.csv does not exists. Skip the rows.
# 1981V1.csv does not exists. Skip the rows.
# 1981W1.csv does not exists. Skip the rows.
# 1982M1.csv does not exists. Skip the rows.
# 1983H1.csv does not exists. Skip the rows.
# 1983J1.csv does not exists. Skip the rows.
# 1983J2.csv does not exists. Skip the rows.
# 1983N1.csv does not exists. Skip the rows.
# 1983N2.csv does not exists. Skip the rows.
# 1983O1.csv does not exists. Skip the rows.
# 1983O2.csv does not exists. Skip the rows.
# 1983R1.csv does not exists. Skip the rows.
# 1983S2.csv does not exists. Skip the rows.
# 1984A1.csv does not exists. Skip the rows.
# 1984K1.csv does not exists. Skip the rows.
# 1984N1.csv does not exists. Skip the rows.
# 1984O2.csv does not exists. Skip the rows.
# 1984Q1.csv does not exists. Skip the rows.
# 1984R1.csv does not exists. Skip the rows.
# 1984S1.csv does not exists. Skip the rows.
# 1984U1.csv does not exists. Skip the rows.
# 1984U2.csv does not exists. Skip the rows.
# 1984V1.csv does not exists. Skip the rows.
# 1984W2.csv does not exists. Skip the rows.
# 1985K1.csv does not exists. Skip the rows.
# 1985R1.csv does not exists. Skip the rows.
# 1985T1.csv does not exists. Skip the rows.
# 1986E1.csv does not exists. Skip the rows.
# 1986N1.csv does not exists. Skip the rows.
# 1986P1.csv does not exists. Skip the rows.
# 1986V1.csv does not exists. Skip the rows.
# 1987A1.csv does not exists. Skip the rows.
# 1987B1.csv does not exists. Skip the rows.
# 1987B2.csv does not exists. Skip the rows.
# 1987F1.csv does not exists. Skip the rows.
# 1987H1.csv does not exists. Skip the rows.
# 1987P1.csv does not exists. Skip the rows.
# 1987Q1.csv does not exists. Skip the rows.
# 1987T1.csv does not exists. Skip the rows.
# 1987T2.csv does not exists. Skip the rows.
# 1987U3.csv does not exists. Skip the rows.
# 1987U4.csv does not exists. Skip the rows.
# 1987W1.csv does not exists. Skip the rows.
# 1987W2.csv does not exists. Skip the rows.
# 1987W3.csv does not exists. Skip the rows.
# 1988A1.csv does not exists. Skip the rows.
# 1988B1.csv does not exists. Skip the rows.
# 1988C1.csv does not exists. Skip the rows.
# 1988F1.csv does not exists. Skip the rows.
# 1988J1.csv does not exists. Skip the rows.
# 1988L1.csv does not exists. Skip the rows.
# 1988M1.csv does not exists. Skip the rows.
# 1988P1.csv does not exists. Skip the rows.
# 1988Q1.csv does not exists. Skip the rows.
# 1988T1.csv does not exists. Skip the rows.
# 1988U1.csv does not exists. Skip the rows.
# 1988W1.csv does not exists. Skip the rows.
# 1988Y1.csv does not exists. Skip the rows.
# 1989A1.csv does not exists. Skip the rows.
# 1989A3.csv does not exists. Skip the rows.
# 1989A5.csv does not exists. Skip the rows.
# 1989A6.csv does not exists. Skip the rows.
# 1989L1.csv does not exists. Skip the rows.
# 1989N3.csv does not exists. Skip the rows.
# 1989Q1.csv does not exists. Skip the rows.
# 1989R1.csv does not exists. Skip the rows.
# 1989S1.csv does not exists. Skip the rows.
# 1989T1.csv does not exists. Skip the rows.
# 1989W1.csv does not exists. Skip the rows.
# 1989X1.csv does not exists. Skip the rows.
# 1989Y1.csv does not exists. Skip the rows.
# 1989Y2.csv does not exists. Skip the rows.
# 1990E1.csv does not exists. Skip the rows.
# 1990K1.csv does not exists. Skip the rows.
# 1990M1.csv does not exists. Skip the rows.
# 1990N1.csv does not exists. Skip the rows.
# 1991A2.csv does not exists. Skip the rows.
# 1991B1.csv does not exists. Skip the rows.
# 1991C3.csv does not exists. Skip the rows.
# 1991F2.csv does not exists. Skip the rows.
# 1991L3.csv does not exists. Skip the rows.
# 1991L4.csv does not exists. Skip the rows.
# 1991Q1.csv does not exists. Skip the rows.
# 1991R1.csv does not exists. Skip the rows.
# 1991T2.csv does not exists. Skip the rows.
# 1991X2.csv does not exists. Skip the rows.
# 1991Y1.csv does not exists. Skip the rows.
# 1992A1.csv does not exists. Skip the rows.
# 1992B1.csv does not exists. Skip the rows.
# 1992F1.csv does not exists. Skip the rows.
# 1992J1.csv does not exists. Skip the rows.
# 1992J2.csv does not exists. Skip the rows.
# 1992N1.csv does not exists. Skip the rows.
# 1992Q2.csv does not exists. Skip the rows.
# 1992U1.csv does not exists. Skip the rows.
# 1992W1.csv does not exists. Skip the rows.
# 1993A1.csv does not exists. Skip the rows.
# 1993F1.csv does not exists. Skip the rows.
# 1993K1.csv does not exists. Skip the rows.
# 1993Q1.csv does not exists. Skip the rows.
# 1993Y1.csv does not exists. Skip the rows.
# 1994E1.csv does not exists. Skip the rows.
# 1994E2.csv does not exists. Skip the rows.
# 1994J2.csv does not exists. Skip the rows.
# 1994N1.csv does not exists. Skip the rows.
# 1994T1.csv does not exists. Skip the rows.
# 1995O1.csv does not exists. Skip the rows.
# 1995Q1.csv does not exists. Skip the rows.
# 1995Q2.csv does not exists. Skip the rows.
# 1995Y1.csv does not exists. Skip the rows.
# 1996A2.csv does not exists. Skip the rows.
# 1996B1.csv does not exists. Skip the rows.
# 1996B2.csv does not exists. Skip the rows.
# 1996B3.csv does not exists. Skip the rows.
# 1996B4.csv does not exists. Skip the rows.
# 1996B5.csv does not exists. Skip the rows.
# 1996D1.csv does not exists. Skip the rows.
# 1996E1.csv does not exists. Skip the rows.
# 1996E2.csv does not exists. Skip the rows.
# 1996F2.csv does not exists. Skip the rows.
# 1996H1.csv does not exists. Skip the rows.
# 1996L1.csv does not exists. Skip the rows.
# 1996L2.csv does not exists. Skip the rows.
# 1996M1.csv does not exists. Skip the rows.
# 1996M2.csv does not exists. Skip the rows.
# 1996M3.csv does not exists. Skip the rows.
# 1996N1.csv does not exists. Skip the rows.
# 1996N3.csv does not exists. Skip the rows.
# 1996O1.csv does not exists. Skip the rows.
# 1996O2.csv does not exists. Skip the rows.
# 1996O3.csv does not exists. Skip the rows.
# ...
# 2018R4.csv does not exists. Skip the rows.
# 2018R5.csv does not exists. Skip the rows.
# 2018S2.csv does not exists. Skip the rows.
# 2018S3.csv does not exists. Skip the rows.
# Figure saved: ../fig/2018U1.png
# 2018V1.csv does not exists. Skip the rows.
# 2018V2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2018VN2.png
# 2018V4.csv does not exists. Skip the rows.
# 2018V5.csv does not exists. Skip the rows.
# 2018W1.csv does not exists. Skip the rows.
# 2018W2.csv does not exists. Skip the rows.
# 2018X2.csv does not exists. Skip the rows.
# 2018X3.csv does not exists. Skip the rows.
# 2018Y1.csv does not exists. Skip the rows.
# 2018Y2.csv does not exists. Skip the rows.
# 2019A1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2019A2.png
# Figure saved: ../fig/2019A3.png
# Figure saved: ../fig/2019A4.png
# 2019A5.csv does not exists. Skip the rows.
# 2019A6.csv does not exists. Skip the rows.
# 2019A9.csv does not exists. Skip the rows.
# 2019B1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2019B2.png
# 2019B3.csv does not exists. Skip the rows.
# 2019C1.csv does not exists. Skip the rows.
# 2019D1.csv does not exists. Skip the rows.
# 2019E3.csv does not exists. Skip the rows.
# 2019F1.csv does not exists. Skip the rows.
# 2019F2.csv does not exists. Skip the rows.
# 2019G2.csv does not exists. Skip the rows.
# 2019G4.csv does not exists. Skip the rows.
# 2019GG21.csv does not exists. Skip the rows.
# 2019H1.csv does not exists. Skip the rows.
# 2019J1.csv does not exists. Skip the rows.
# 2019J2.csv does not exists. Skip the rows.
# 2019J3.csv does not exists. Skip the rows.
# 2019JU6.csv does not exists. Skip the rows.
# 2019K1.csv does not exists. Skip the rows.
# 2019K4.csv does not exists. Skip the rows.
# 2019K5.csv does not exists. Skip the rows.
# 2019K6.csv does not exists. Skip the rows.
# 2019K7.csv does not exists. Skip the rows.
# 2019K8.csv does not exists. Skip the rows.
# 2019L1.csv does not exists. Skip the rows.
# 2019L2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2019LD2.png
# Figure saved: ../fig/2019L3.png
# Figure saved: ../fig/2019LM4.png
# 2019LB7.csv does not exists. Skip the rows.
# 2019M3.csv does not exists. Skip the rows.
# 2019M4.csv does not exists. Skip the rows.
# 2019N1.csv does not exists. Skip the rows.
# 2019NJ3.csv does not exists. Skip the rows.
# 2019O2.csv does not exists. Skip the rows.
# 2019O3.csv does not exists. Skip the rows.
# 2019Q1.csv does not exists. Skip the rows.
# 2019Q3.csv does not exists. Skip the rows.
# 2019Q4.csv does not exists. Skip the rows.
# Figure saved: ../fig/2019S2.png
# Figure saved: ../fig/2019S3.png
# 2019S4.csv does not exists. Skip the rows.
# 2019T2.csv does not exists. Skip the rows.
# 2019T3.csv does not exists. Skip the rows.
# Figure saved: ../fig/2019T4.png
# 2019T5.csv does not exists. Skip the rows.
# 2019T6.csv does not exists. Skip the rows.
# 2019U4.csv does not exists. Skip the rows.
# Figure saved: ../fig/2019U5.png
# 2019U6.csv does not exists. Skip the rows.
# 2019V1.csv does not exists. Skip the rows.
# 2019V2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2019W1.png
# 2019X1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2019X2.png
# 2019Y1.csv does not exists. Skip the rows.
# 2019Y4.csv does not exists. Skip the rows.
# 2019Y5.csv does not exists. Skip the rows.
# 2020A2.csv does not exists. Skip the rows.
# 2020A3.csv does not exists. Skip the rows.
# 2020A4.csv does not exists. Skip the rows.
# 2020B2.csv does not exists. Skip the rows.
# 2020B3.csv does not exists. Skip the rows.
# 2020B4.csv does not exists. Skip the rows.
# 2020F2.csv does not exists. Skip the rows.
# 2020F3.csv does not exists. Skip the rows.
# 2020F5.csv does not exists. Skip the rows.
# 2020F6.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020F7.png
# 2020F8.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020G1.png
# 2020H2.csv does not exists. Skip the rows.
# 2020H3.csv does not exists. Skip the rows.
# 2020H4.csv does not exists. Skip the rows.
# 2020H5.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020H6.png
# 2020H7.csv does not exists. Skip the rows.
# 2020H8.csv does not exists. Skip the rows.
# 2020H11.csv does not exists. Skip the rows.
# 2020J1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020K1.png
# 2020K2.csv does not exists. Skip the rows.
# 2020K3.csv does not exists. Skip the rows.
# 2020K4.csv does not exists. Skip the rows.
# 2020K5.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020K6.png
# 2020K7.csv does not exists. Skip the rows.
# 2020K8.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020K9.png
# 2020M1.csv does not exists. Skip the rows.
# 2020M3.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020MK4.png
# 2020M5.csv does not exists. Skip the rows.
# 2020N1.csv does not exists. Skip the rows.
# 2020N2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020O2.png
# Figure saved: ../fig/2020O3.png
# 2020P1.csv does not exists. Skip the rows.
# 2020P3.csv does not exists. Skip the rows.
# 2020PV6.csv does not exists. Skip the rows.
# 2020Q1.csv does not exists. Skip the rows.
# 2020Q2.csv does not exists. Skip the rows.
# 2020R2.csv does not exists. Skip the rows.
# 2020R4.csv does not exists. Skip the rows.
# 2020R5.csv does not exists. Skip the rows.
# 2020R6.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020R7.png
# 2020S1.csv does not exists. Skip the rows.
# 2020S2.csv does not exists. Skip the rows.
# 2020S3.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020S4.png
# Figure saved: ../fig/2020S5.png
# 2020S7.csv does not exists. Skip the rows.
# 2020S8.csv does not exists. Skip the rows.
# 2020T2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020T3.png
# 2020T4.csv does not exists. Skip the rows.
# 2020T5.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020U2.png
# 2020U3.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020U4.png
# Figure saved: ../fig/2020U5.png
# Figure saved: ../fig/2020V2.png
# Figure saved: ../fig/2020V3.png
# Figure saved: ../fig/2020V4.png
# 2020W1.csv does not exists. Skip the rows.
# 2020W5.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020WJ5.png
# 2020X1.csv does not exists. Skip the rows.
# 2020X2.csv does not exists. Skip the rows.
# 2020X4.csv does not exists. Skip the rows.
# Figure saved: ../fig/2020Y2.png
# 2020Y3.csv does not exists. Skip the rows.
# 2021A1.csv does not exists. Skip the rows.
# 2021A2.csv does not exists. Skip the rows.
# 2021A4.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021A5.png
# 2021A6.csv does not exists. Skip the rows.
# 2021A7.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021A9.png
# 2021A10.csv does not exists. Skip the rows.
# 2021B2.csv does not exists. Skip the rows.
# 2021B3.csv does not exists. Skip the rows.
# 2021C1.csv does not exists. Skip the rows.
# 2021C2.csv does not exists. Skip the rows.
# 2021C3.csv does not exists. Skip the rows.
# 2021C4.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021C5.png
# 2021C6.csv does not exists. Skip the rows.
# 2021D1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021D2.png
# Figure saved: ../fig/2021E3.png
# 2021F1.csv does not exists. Skip the rows.
# 2021G1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021G2.png
# 2021G3.csv does not exists. Skip the rows.
# 2021HS.csv does not exists. Skip the rows.
# 2021J1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021J2.png
# Figure saved: ../fig/2021J3.png
# 2021K1.csv does not exists. Skip the rows.
# 2021K2.csv does not exists. Skip the rows.
# 2021K3.csv does not exists. Skip the rows.
# 2021L2.csv does not exists. Skip the rows.
# 2021L3.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021N1.png
# Figure saved: ../fig/2021N2.png
# 2021N3.csv does not exists. Skip the rows.
# 2021O1.csv does not exists. Skip the rows.
# 2021O3.csv does not exists. Skip the rows.
# 2021P1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021P2.png
# 2021P3.csv does not exists. Skip the rows.
# 2021P4.csv does not exists. Skip the rows.
# 2021PE20.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021Q3.png
# Figure saved: ../fig/2021Q4.png
# Figure saved: ../fig/2021Q5.png
# Figure saved: ../fig/2021Q6.png
# 2021QM45.csv does not exists. Skip the rows.
# 2021R1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021R2.png
# 2021R3.csv does not exists. Skip the rows.
# 2021R4.csv does not exists. Skip the rows.
# 2021R5.csv does not exists. Skip the rows.
# 2021R6.csv does not exists. Skip the rows.
# 2021R7.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021R8.png
# Figure saved: ../fig/2021S1.png
# Figure saved: ../fig/2021S3.png
# Figure saved: ../fig/2021S4.png
# 2021T1.csv does not exists. Skip the rows.
# 2021T2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021T4.png
# 2021TR81.csv does not exists. Skip the rows.
# 2021U1.csv does not exists. Skip the rows.
# 2021U3.csv does not exists. Skip the rows.
# 2021U4.csv does not exists. Skip the rows.
# 2021U5.csv does not exists. Skip the rows.
# 2021V1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021V2.png
# Figure saved: ../fig/2021X1.png
# 2021X2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2021Y1.png
# 2022A1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022A2.png
# Figure saved: ../fig/2022A3.png
# 2022B1.csv does not exists. Skip the rows.
# 2022B4.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022BV9.png
# 2022C1.csv does not exists. Skip the rows.
# 2022C2.csv does not exists. Skip the rows.
# 2022C3.csv does not exists. Skip the rows.
# 2022D1.csv does not exists. Skip the rows.
# 2022D2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022E2.png
# Figure saved: ../fig/2022E3.png
# Figure saved: ../fig/2022F1.png
# 2022F2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022H1.png
# 2022J1.csv does not exists. Skip the rows.
# 2022J2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022JK5.png
# 2022K1.csv does not exists. Skip the rows.
# 2022L1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022L2.png
# 2022L3.csv does not exists. Skip the rows.
# 2022L4.csv does not exists. Skip the rows.
# 2022N1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022N2.png
# Figure saved: ../fig/2022O1.png
# 2022O2.csv does not exists. Skip the rows.
# 2022P1.csv does not exists. Skip the rows.
# 2022P2.csv does not exists. Skip the rows.
# 2022P3.csv does not exists. Skip the rows.
# 2022Q2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022QE78.png
# Figure saved: ../fig/2022R1.png
# 2022R2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022R3.png
# 2022R4.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022R5.png
# Figure saved: ../fig/2022R6.png
# 2022S1.csv does not exists. Skip the rows.
# 2022S3.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022S4.png
# 2022S5.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022T1.png
# Figure saved: ../fig/2022U1.png
# 2022U2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2022U3.png
# Figure saved: ../fig/2022U4.png
# Figure saved: ../fig/2022V2.png
# Figure saved: ../fig/2022W1.png
# 2022W2.csv does not exists. Skip the rows.
# 2022W3.csv does not exists. Skip the rows.
# 2022Y1.csv does not exists. Skip the rows.
# 2022Y2.csv does not exists. Skip the rows.
# 2023A1.csv does not exists. Skip the rows.
# 2023A2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2023A3.png
# Figure saved: ../fig/2023B1.png
# 2023B2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2023B3.png
# Figure saved: ../fig/2023C2.png
# 2023E1.csv does not exists. Skip the rows.
# 2023F1.csv does not exists. Skip the rows.
# 2023F2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2023F3.png
# Figure saved: ../fig/2023H1.png
# 2023H2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2023H3.png
# Figure saved: ../fig/2023H5.png
# Figure saved: ../fig/2023JN16.png
# 2023K1.csv does not exists. Skip the rows.
# 2023M1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2023M2.png
# Figure saved: ../fig/2023M4.png
# Figure saved: ../fig/2023P1.png
# Figure saved: ../fig/2023Q1.png
# Figure saved: ../fig/2023Q2.png
# Figure saved: ../fig/2023R1.png
# Figure saved: ../fig/2023R2.png
# Figure saved: ../fig/2023RN3.png
# Figure saved: ../fig/2023RS61.png
# Figure saved: ../fig/2023S1.png
# 2023S2.csv does not exists. Skip the rows.
# 2023S3.csv does not exists. Skip the rows.
# Figure saved: ../fig/2023T1.png
# 2023T2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2023T3.png
# Figure saved: ../fig/2023TD22.png
# Figure saved: ../fig/2023U1.png
# Figure saved: ../fig/2023V1.png
# Figure saved: ../fig/2023V2.png
# Figure saved: ../fig/2023V3.png
# Figure saved: ../fig/2023V4.png
# 2023V5.csv does not exists. Skip the rows.
# Figure saved: ../fig/2023V6.png
# 2023X1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2023X2.png
# Figure saved: ../fig/2023X3.png
# Figure saved: ../fig/2023X4.png
# Figure saved: ../fig/2023X7.png
# 2023Y1.csv does not exists. Skip the rows.
# 2023Y2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2024A1.png
# Figure saved: ../fig/2024A2.png
# Figure saved: ../fig/2024B1.png
# Figure saved: ../fig/2024B2.png
# Figure saved: ../fig/2024C1.png
# Figure saved: ../fig/2024C2.png
# Figure saved: ../fig/2024C3.png
# 2024C4.csv does not exists. Skip the rows.
# Figure saved: ../fig/2024D1.png
# Figure saved: ../fig/2024E1.png
# Figure saved: ../fig/2024E2.png
# 2024F1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2024F2.png
# 2024FG9.csv does not exists. Skip the rows.
# Figure saved: ../fig/2024G1.png
# Figure saved: ../fig/2024G2.png
# Figure saved: ../fig/2024G3.png
# Figure saved: ../fig/2024G4.png
# Figure saved: ../fig/2024G5.png
# Figure saved: ../fig/2024G6.png
# Figure saved: ../fig/2024G7.png
# Figure saved: ../fig/2024J1.png
# Figure saved: ../fig/2024J2.png
# Figure saved: ../fig/2024J3.png
# Figure saved: ../fig/2024J4.png
# Figure saved: ../fig/2024K1.png
# Figure saved: ../fig/2024L1.png
# Figure saved: ../fig/2024L2.png
# Figure saved: ../fig/2024L3.png
# Figure saved: ../fig/2024L5.png
# Figure saved: ../fig/2024M1.png
# Figure saved: ../fig/2024N1.png
# Figure saved: ../fig/2024N3.png
# Figure saved: ../fig/2024N4.png
# Figure saved: ../fig/2024O1.png
# Figure saved: ../fig/2024O2.png
# 2024OC2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2024PN7.png
# Figure saved: ../fig/2024Q1.png
# Figure saved: ../fig/2024Q3.png
# Figure saved: ../fig/2024Q4.png
# 2024R1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2024R2.png
# Figure saved: ../fig/2024R3.png
# Figure saved: ../fig/2024R4.png
# Figure saved: ../fig/2024S1.png
# Figure saved: ../fig/2024S2.png
# Figure saved: ../fig/2024T1.png
# Figure saved: ../fig/2024T2.png
# Figure saved: ../fig/2024T3.png
# Figure saved: ../fig/2024T5.png
# Figure saved: ../fig/2024U1.png
# Figure saved: ../fig/2024V1.png
# 2024V2.csv does not exists. Skip the rows.
# Figure saved: ../fig/2024W1.png
# Figure saved: ../fig/2024X1.png
# Figure saved: ../fig/2024X2.png
# Figure saved: ../fig/2024X3.png
# Figure saved: ../fig/2024X4.png
# Figure saved: ../fig/2024XK14.png
# Figure saved: ../fig/2024Y1.png
# Figure saved: ../fig/2025A2.png
# Figure saved: ../fig/2025A3.png
# Figure saved: ../fig/2025A4.png
# Figure saved: ../fig/2025A6.png
# Figure saved: ../fig/2025B1.png
# Figure saved: ../fig/2025B2.png
# Figure saved: ../fig/2025C1.png
# 2025D1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2025D2.png
# Figure saved: ../fig/2025D3.png
# Figure saved: ../fig/2025D4.png
# Figure saved: ../fig/2025D5.png
# Figure saved: ../fig/2025D6.png
# Figure saved: ../fig/2025E1.png
# Figure saved: ../fig/2025F1.png
# Figure saved: ../fig/2025F2.png
# Figure saved: ../fig/2025J1.png
# Figure saved: ../fig/2025K1.png
# Figure saved: ../fig/2025K2.png
# Figure saved: ../fig/2025K3.png
# Figure saved: ../fig/2025K4.png
# Figure saved: ../fig/2025L1.png
# Figure saved: ../fig/2025L2.png
# 2025M1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2025M2.png
# Figure saved: ../fig/2025M3.png
# Figure saved: ../fig/2025N1.png
# Figure saved: ../fig/2025N2.png
# Figure saved: ../fig/2025O2.png
# 2025Q1.csv does not exists. Skip the rows.
# Figure saved: ../fig/2025Q2.png
# Figure saved: ../fig/2025R1.png
# Figure saved: ../fig/2025R2.png
# Figure saved: ../fig/2025R3.png
